# %%
file_path = "dataset/all_data.txt"

# %%
texts=[]
criterias=["주소"]
with open(file_path,'r') as f:
    for text in f.readlines():
        for criteria in criterias:
            if criteria in text:
                texts.append(text)
                break
print(len(texts))
# Out:
# 7549

# %%
for a in texts:
    print(a)
# Out:
# 무엇이 옳은가 그른 것인지 판단해주소서!
#
# 그건 내 이메일 주소고 닉네임을 맞춰라
#
# 옛날 주소로간거?
#
# 그래 메일 주소 알려줘.
#
# 근데 우리 집 주소 삼일로야...
#
# 거기 주소를 아직 확실히 몰라서 키키
#
# 일본의 현주소 같애
#
# 어 잠시만 내가 주소 찍어 줄께
#
# 어제가 주소지 기준으로 1차 분양이었고
#
# 나는 주소 다 찍어보고 최단 거리로 경로 설정 한다 키키
#
# 키키 하나하나 주소 치는 것도 힘들겠다
#
# 다름이 아니라 저는 주소를 변경했는데 이전 집 주소로 배송이 되었네요
#
# 제가 여러번 주소 설정하고 확인했는데 어떻게 이런 일이 있을 수 있죠?
#
# 저희 집 주소로 다시 배송해 주실 수 있을까요?
#
# 네~ 고객님 반품 처리하고 회수하고 고객님 주소로 다시 보내드리겠습니다.
#
# 이름이랑 주소 좀 알려줘
#
# 응 심심한데 병원 주소 불러줄게
#
# 주소 보내줄게~
#
# **의 식당 주소는 **집 해줄 거지?
#
# 근데... 주소 바꾸는게 왜없어?
#
# 그럴까? 그럼 너네 편의점 주소만 불러줘 하하
#
# 그래 내가 카톡으로 주소 보내줄게 키키
#
# 키키 뭐 전화하니까 나보고 전역했냐고 해서 그렇다고 하니까 주소 알려주더라
#
# 네이버 블로그 같은데는 쿠팡 주소 달면 저품질 온다고 했는데
#
# 주소 링크 따라 다른 사람이 구매하면 수수료를 주는 형식이라 경로만 알면 괜찮을듯
#
# 고마워! 내 메일주소 알지?
#
# 쿠팡 앱에서 31만명이 넘는 회원의 이름과 주소가 유출되는 일이 발생했대
#
# 친구가 이번에 쇼핑몰 운영한다고 주소를 보냈어
#
# 그래 그럼 내가 배구경기장 주소 보낼게 지금!
#
# 근데 우리 집 도로명 주소가 삼일로 어쩌고야 신기하쥐
#
# 주소 알려줘 하하
#
# 상품 근처에 주소 복사하는거 있지 않아요?
#
# 근데 친구 집으로 보내려면 또 집주소도 물어봐야하고... 입력해야하고 조금 귀찮네
#
# 친구 입장에서도 집주소 안가르쳐줘도 되고 그게 더 편할거야 아마!
#
# 그러시군요. 그럼 운전하고 오시니까 주소를 다시 찍어드릴게요.
#
# 휴양림주소로 내비게이션 안내로 가면 그 근처가면 안내표지판 있는거니?
#
# 집 주소와 거리가 먼 곳은 5000원이요
#
# 그거 호적상 같은 주소지에 거주하는 가족만 가능해
#
# 택배거래는 내 주소가 알려지는가잖아
#
# 나도 그냥 메일 주소로만 만들어.
#
# 주소를 다른 데로 하면 된다는데 자취하는 것도 아니니깐 애매하더라구~
#
# 그게 요즘에는 확인을 더 많이 해서 주소만 옮기면 잘못 걸리면 벌금 물어 ㅠㅠ
#
# 난 배대지 주소 적어서 해도 편하더라
#
# 잊어버리고 주소 입력을 안 했어.
#
# 그래 내가 병원 주소 보내줄게
#
# 이사 간 데 주소 안 알려줬어?
#
# 이사 간 주소는 안 알려줬는데;
#
# 메일주소가 잘못봣나 했는데 컬쳐랜드인거 같고
#
# 마지막에 제보해달라고 메일주소 나오든데
#
# 너네 집 주소 좀
#
# 우리 집 주소? 키키
#
# 그럼 집 주소 보내 주라 `
#
# 그렇구나 그럼 동생한테 부대 주소를 보내달라고 해
#
# 근데 더 신기한 건 신혼집 주소가 어쩌고 삼일로야
#
# 맞아 주소지를 바꾸는 것도 손이 많이 가더라구.
#
# 평택 미군기지 근처는 미국 주소로 돼 있다고 들었어!
#
# 근데 우리집 도로명 주소가 삼일로 어쩌고 야!  진짜 신기하지?
#
# 내가 다녀왔던 곳 몇 개 주소 보내줄게
#
# 키키 왜 너네집 주소 내 안다!
#
# 내가 일단 주소 보내줄테니 한번 연락해봐
#
# 그 알림 올텐데 알림 보면 주소 나와있지 않나?
#
# 응응 수정커뮤니티센터! 주소 나와있는데 봐도 못 찾겠어서 ㅠㅠ
#
# 그럼 주소 찍고 바로 운전해서 오면 되겠네.
#
# 인강 주소좀 알려줘!
#
# 나도 인강 주소 좀 알려줘~
#
# 그치 근데 페이지 만드는 게 생각보다 괜찮아서 쇼핑 페이지는 스토어로 만들고 거래가 많아지게끔 SNS에 주소를 올려놔도 좋을 거 같애
#
# 거기 사이트 주소 좀 줘봐
#
# 엉 키키 **이 시아버님은 경주에 주소지라 경주시 지원금도 10만원 더받았대
#
# 지금 주소만 네번째 쓰는중
#
# 맞아 ㅠㅠ 막 미행하고 집 앞에 잠복해서 주소 알아내고 하는 과정 보여주는데 진짜 무섭더라...
#
# 요즘은 연애 초반에는 집 주소 잘 안 가르쳐준다면서요
#
# 그치만 안 좋게 헤어졌는데 그 남자가 내 집 주소를 안다? 무섭지 않아요?
#
# 아 맞아요... 안 알려줬는데도 사진에 있는 택배 상자 주소 보고 알아내서 살인 한 그거 보고 저도 엄청 놀랐어요
#
# 나 요즘 보는 영상있는데 주소 알려줘?
#
# 난 주소지를 아직 이전하지 못해서 혜택도 없어
#
# 주여... 비를 내려주소서 키키
#
# 아직 수술 날짜는 안잡았구 회사 일정이랑 생각해서 날짜 생각해보려고! 병원주소는 내가 보내줄게
#
# 응응 여섯 시에 내가 나중에 알려주는 주소로 가면 된다
#
# 난 그냥 어딜 정해서 사는 거보다 그냥 네이버에 치면 나와서 주소창은 잘 몰라
#
# 응 진짜 신기하더라 거기는 주소를 안 알려주더라고
#
# 엥? 주소를 안 알려주면 어떻게 가?
#
# 내가 배송주소 알려주면 될까?
#
# 응 키키 배송주소만 나한테 보내줘
#
# 우리 집 주소 잘못 찍은 거 아님?
#
# 그 주소가 혹시 대한민국인가?
#
# 그래 저번에 내가 너거 이메일 주소 알려줬는데
#
# 나는 택배거래에 주소 잘못 쓰셔서 옆집으로 간적은 있어ㅠㅠ
#
# 나도 사이트 주소 알려줄 수 있어?
#
# 나도 사이트 주소 부탁해! 내가 직접 찾아볼게
#
# 한국 주소로 쓰면 또 편하긴 한데 키키
#
# 언니가 신혼집주소 말고 우리집 주소로 신청해놨나보지.
#
# 가평에 있는 곳인데 내가 주소를 따로 보내줄게!
#
# 와 주소 알려줘 구경 갈게 키키
#
# 앙게써 주소 썬셋로그 치면 나와!
#
# 우리 집 주소 모르잖아
#
# 프론트랑 백엔드랑 동일한 주소를 정해서 그 주소에서 전달 받는거야
#
# 주소만 찍으면 그 앞에 데려다 주니 키키
#
# 응응 회사 주소로하면 뭔가 이상해서요
#
# 아 맞아... 선물하기로 보내놓고 주소입력을 안함
#
# 그치만 아무래도 불편하지 않을까요? 자기 집 주소도 노출 해야하고...
#
# 오후 3시에 내가 알려준 주소로 오면 돼^^
#
# 응. **이가 편지 한 번 써달라고 주소를 보냈었던 거 같은데 한 번을 안 써줬어
#
# 네! 앱 켜시면 맨 위에 검색창에다 주소나 건물명 검색하시면 돼요.
#
# 풋살장 주소 찍어 보내줄게!
#
# 주소 보내놔줘!
#
# 근데 주소가... 경산이고잉 키키
#
# 마침 딱 필요해가지고 살려고 했는데 주소 공유 좀 해줄래
#
# 나는 주소 공유해 줘! 한번 훑어보게!
#
# 이번주 목까지 보고 주소먼저 받고 등기 띄어서 은행가서 조회해봐야 하나 고민중
#
# 응 키키 혹시라도 인터넷에서 찾으면... 주소 좀 공유해줘
#
# 주소 보내놔줘
#
# 그럼 제게 보내는 것은 어떠세요? 주소 말씀드리겠습니다.
#
# 키키 요새 아무나 다 해서 집 주소를 몰라서 그래
#
# 그럼 내가 풋살장 주소 보내줄게!
#
# 거기 홈페이지 주소좀 알려줘봐
#
# 그거 주소 따 줄 수는 없나
#
# 너 주소는 누가 써준다고 했어?
#
# 근데 친구 집으로 보내려면 또 집주소도 물어봐야하고... 입력해야하고 조금 귀찮네
#
# 친구 입장에서도 집주소 안가르쳐줘도 되고 그게 더 편할거야 아마!
#
# 이사하면 주소변경 3개월만 되나?
#
# 근데 우리집 주소 어쩌고 삼일로 다
#
# 그렇지 주소지 기준이니까
#
# 그러니까 이병들은 일단 선임들 이름 주소 번호 총번 다 외우게 시켜야 해
#
# 그럼 집 주소를 보내 주시겠어요?
#
# 제가 카톡으로 주소 보내드릴게요
#
# 그럼 집 주소를 보내 주시겠어요?
#
# 제가 카톡으로 주소 보내드릴게요
#
# 주소랑 찾았다는데 지금 집에 있겠냐고...
#
# 좋은거 잇으면 알려주소
#
# 그럼 일단 엄마가 쇼핑몰 주소 알려줄 테니까 들어가서 한번 구경해봐
#
# 내가 자세한 주소는 전화로 알려줄게 가서 사
#
# 선물하기로 하면 받는 사람이 주소를 적자나 그거 진짜 좋은거 같애
#
# 나는 택배 거래에 주소 잘못 쓰셔서 옆집으로 간 적은 있어ㅠㅠ
#
# 그래 그러면 주소랑 보내줘 보내줄게
#
# 아니 근데 대형마트에 입점 돼 있다고 해서 마트 소속인 건 아니지 않나...? 주소지는 여기로 돼있으니...
#
# 내 주소 *-* *-* *-*
#
# 전부 다 울집 주소다 키키 개이득
#
# 오늘 당근 마켓 동네 생활에 누가 동네 붕어빵 집 주소 가르쳐줘서 꿀이였어!
#
# 나도 한번 가봐야겠다! 주소 알려줄래?
#
# 주소 보내드릴게요 시간 지켜주세요
#
# IP주소를 등록해 놓거든
#
# 어머니 집 주소 좀 찍어 주고
#
# 아 맞아 봤어 댓글 보니까 이게 머 주소지를 하나하나 보고 담는 게 아니라 그렇다더라?
#
# 혹시 키키 너네 집에 주소 좀 옮겨놓을 수 있을까 키키 동생...
#
# 근데 우리 집 주소 삼일로 야
#
# 집이동구였는데 수성구 삼촌집에 주소이전해서
#
# 서큘 망가져서 뜯어보고 만보기 기계도 뜯어서 납땜좀 해주소
#
# 맞아! 내가 홈페이지 주소 공유해 줄 테니까 한번 들어가서 봐봐
#
# 앱에는 주소입력만 하면 되니까
#
# 명절 선물 때문에 사무실 주소 물어본 카톡이 오늘 다얔 키키
#
# 옴매매 ~ 머 119도 주소 직접 받아서 적었다더라
#
# 음...나는 그냥 택배 서비스 되는 편의점인지 확인하고서 거기 주소 쓰고 부쳤어!
#
# 가격은 똑같은 걸로 알고 있는데... 해외 배송도 아마 주소를 거기로 입력하면 받을 수 있는 걸로 알고 있어!
#
# 38세가 되는 순간 주소를 등록 한대. 완전 꼼수야.
#
# 응. 메일 주소 알려줄테니까 여기로 보내.
#
# 그래그래 주소 보내줄게
#
# 딸 좀 나가 놀게 해주소
#
# 불쌍한 ** 자식... 주소 찍어둬...
#
# 말만 그렇게 하지 말고 저녁에 맛난 거나 해 주소
#
# 원지에  졸맛집 주소 좀...
#
# 그래 주소 불러
#
# 그런데 주소지 정보가 잘못된 경우나 사진이 몇년이 지났는데도
#
# 고객님 혹시 주소가 어떻게 되시나요
#
# 주소는 전북 익산 #@주소#이에요
#
# 네 그럼 같은 주소로 보내주세요
#
# 네 주소 확인해 드리겠습니다 서울특별시 서초구 #@주소# 맞습니까
#
# 네 주소 맞습니다
#
# 확인 후 환불 가능 여부 및 반송 주소 안내를 받으실 수 있습니다
#
# 해당 강좌 신청 시에 주소작성 하셨습니까
#
# 네 주소작성 했습니다
#
# 네 집 주소 적으셨으면 집으로 받으실 수 있습니다
#
# 현재 교재 배송 전이라면 주소 변경 가능하십니다
#
# 네 확인되셨고요 #@이름# 고객님 현재 교재 배송 전이라 주소 변경 가능하십니다
#
# 회원가입하셨을 때 적어주신 이메일 주소 #@소속#메일꺼 기억하세요
#
# 출고가 완료된 상태에선 주소 변경이 불가능합니다
#
# 네네 그러면 책 보낼 주소 좀 알려주시겠어요
#
# 공지 보니까 회원정보에 있는 주소로 간다는데 제가 이사를 했어요
#
# 죄송하지만 아마 이사 전 주소로 배송이 되실 거예요
#
# 까먹고 예전 주소로 결제해서 변경해야 할것같아요
#
# 네 #@이름#님 확인되셨고요 현재 출고 전이라 주소 변경 가능합니다
#
# 네 그럼 #@주소#를 #@주소#으로 좀 바꿔주세요
#
# 네 주소 바꿔드렸습니다
#
# 주소 입력하라는 얘기가 없이 발송이 됐다는데요
#
# 이벤트 상품 발송은 회원정보에 기재되어 있으신 주소로 발송되세요
#
# 회원님 번호로 반품 주소지를 보내드릴 텐데요 이 주소지로 착불 반송처리해 주실 수 있을까요
#
# 네 맞아요 지금 주소 보내주시면 바로 보낼게요
#
# 네 자택 주소 부산시 부산진구 #@주소# 맞으실까요
#
# 예 지금 불러주신 주소 맞습니다
#
# 누락된 교재명과 재배송 받으실 성함 연락처 주소 불러주시겠어요
#
# 연락처는 #@전번#이고 주소는 서울시 강서구 #@주소#입니다
#
# 어디에 반송해야 하는지 주소 확인하려고 전화드렸어요
#
# 아 그러시면 주소가 경기 부천시 소사구 #@주소# 입니다
#
# 네 성함과 연락처 주소 확인 부탁드립니다
#
# 주소는 #@주소# 에요
#
# 네 국내 주소지로 받으신 후에 개별적으로 보내셔야 합니다
#
# #@전번# 여기로 주소 보내주세요
#
# 제 메일 주소 알려드리면 될까요
#
# 이메일 주소가 #@계정# 맞으실까요
#
# 교재명과 교환 받으실 성함 연락처 주소 불러주시겠어요
#
# 연락처는 #@전번#이고 주소는 서울시 송파구 #@주소#예요
#
# 네 연락처에 등록된 주소로 보내드리면 될까요
#
# 네 등록된 주소로 보내주세요
#
# 네 등록된 주소 확인하겠습니다
#
# 서울특별시 #@주소# 맞습니까
#
# 네 주소 맞아요
#
# 네 그러면 메일 주소 좀 알려주세요
#
# 네 핸드폰 번호로 이메일 주소랑 내용 전달드렸습니다
#
# 교환 받으실 주소 우편번호와 성함 연락처 남겨주시겠습니까
#
# 주소는 서울시 노원구 #@주소#구요 우편번호는 #@번호#입니다
#
# 그러시면 먼저 홈페이지 주소가 #@URL#이 맞으신가요
#
# 예 불러주신 주소가 맞아요
#
# 네네 성함 연락처 주소 불러주시겠습니까
#
# 네 확인 되셨습니다 주소지는 강서구 #@주소# 맞으실까요
#
# 어 네 그 주소 맞아요 거기로 보내주세요
#
# 사업자번호 및 메일 주소 정확하게 기재 부탁드립니다
#
# 네 성함과 연락처 받으실 주소 확인 부탁드립니다
#
# 네 주소 말씀해 주시겠습니까
#
# 주소는 #@주소#입니다
#
# 네 반송 보낼 주소 좀 알려주세요
#
# #@주소# 입니다
#
# 아 네 제가 등록하신 주소로 다시 재발송 요청드렸습니다
#
# #@이름# 님 전화번호로 이메일 주소 문자 전송해드릴게요
#
# 네 그럼 등록된 주소로 다시 배송해드리겠습니다
#
# 네 메일 주소 불러 주시겠어요
#
# 주소가 변경되셔서 못 받으셨을 수 있거든요
#
# 그럼 미리 주소 변경을 해주셨어야 수령이 되셨을 거예요
#
# 제가 자세한 방법이 안내되어 있는 주소 보내드려도 될까요
#
# 네 받으실 이메일 주소 말씀해 주시겠습니다
#
# 네 서울특별시 서초구 #@주소#입니다
#
# 불편하시겠지만 일반 주소로 받으시고 별도로 가셔야 할 것 같습니다
#
# 교재 오기로한 걸 집으로 했어야했는데 주소를 잘못 설정해서요
#
# 네 맞아요 그 주소는 서울시 도봉구 #@주소#로 해주시면 돼요
#
# 네 주소 불러드릴까요
#
# 부산광역시 사상구 #@주소@ #@소속@ 시간제 담당자 앞입니다
#
# 감사드리구요 고객님 주소가 부산시 부산진구 #@주소# 맞으실까요
#
# 예 #@주소# 맞습니다
#
# 저희 반송처 주소로 사용 흔적이 없는 교재를 반송해주시면 됩니다
#
# 네 감사합니다 받으실 주소가 경기도 안산시 다음 어떻게 되시죠
#
# 주소는요 #@주소# 에요
#
# 안녕하세요 혹시 사이트에서 교재 결제한거 주소 바꿀 수 있나요
#
# 제가 주소를 바꿔야 되는데 지금 전화가 길게 안돼서요
#
# 네 고객님 주소 불러 주시면 발송해 드리겠습니다
#
# 아네 집주소는 경북 포항시 남구 #@주소#입니다
#
# 이름은 #@이름# #@주소# 야간 다이어트 요가 저녁 19시 30분이요
#
# 죄송하지만 현재 배송이 시작돼서 주소 변경이 불가능하십니다
#
# 만약에 당첨되면 경품은 어느 주소로 보내주시는 건가요
#
# 회원님의 기본 배송지 주소로 발송됩니다
#
# 그렇군요 알겠습니다 집 주소로 되어 있으니까 괜찮을 것 같아요
#
# 감사합니다 고객님 그러면 배송 주소는요
#
# 예전에 주문 했던 집주소 그대로 살고 있거든요
#
# 같은 주소로 보내주시면 되겠습니다
#
# 거기 홈페이지 주소 좀 알려주세요
#
# 홈페이지 주소는 #@URL#입니다
#
# 서울시 관악구 #@주소# 선물대잔치 담당자 앞으로 보내주세요
#
# 배송지를 지인분 주소로 보내는 건 어떨까 싶습니다
#
# 기본정보상에 입력하신 메일주소로 발송됩니다
#
# 그런데 왜 주소를 입력하라고 하는 건가요
#
# 주소 확인 기간 내 이벤트 페이지에서 신청해주시면 됩니다
#
# 지금 이 주소 확인 기간인가요
#
# #@주소# 매장에서 제품을 구매했는데요
#
# 네 그러면 주소지 그대로 보내드리겠습니다 감사합니다
#
# 근데 이게 이벤트 종료 전에 주소지를 수정을 안 해서요
#
# 예 주소지가 어디로 되있죠
#
# 지금 주소가 경기 오산시 #@주소#으로 되어 있습니다
#
# 홈페이지 주소가 어떻게 되나요
#
# 홈페이지 주소는 #@URL#입니다
#
# 주소도 좀 알려주세요
#
# 네 서울시 #@주소#입니다
#
# 여기 #@주소#인데 서비스센터 자재실 번호 알 수있을까요
#
# 경품 배송은 당첨자 발표 후 주소 수정 기간 있습니다
#
# 그러시면 회원정보 내에 있는 주소 확인 부탁드릴게요
#
# 주소 확인 필요해서요 주소 말씀 부탁 드립니다
#
# #@주소# 이고요 회원 정보와 동일해요
#
# 회원 정보의 주소로 발송 에정 입니다
#
# 그래서 집 주소랑 이름 연락처 말하라고 하던데요
#
# 문자나 주소를 보내드려서 거기다가요
#
# 이메일 주소 확인해 봤는데 정상적으로 입력을 했거든요
#
# 확인하실 수 있습니다 집 주소나 이런 건 안 나오고요
#
# 그래요 그럼 주소를 모르면 못 보내는 건가요
#
# 네 고객님 받으실 분 주소를 모르시면 발송이 불가합니다
#
# #@이름#이고요 주소지를 변경하려고요 받는 사람요
#
# 네 주소지 변경 가능하세요
#
# 네 내일 출발합니다 주소 전달해드리겠습니다
#
# 그러면요 제가 친구네 집 주소 물어서요
#
# 그 경우 당첨자 아이디를 통해 회원정보의 메일주소로 발송해드립니다
#
# 네 그래서 고객님 자택 주소는 동일하게 보낼까요
#
# 배송은 회원정보 상 주소지로 보내주시는 거예요
#
# 아니요 별도 당첨 메일을 통해 주소지 회신을 요청드리고 있어요
#
# 영등포에는 #@주소#에 매장이 있습니다
#
# 예 #@주소# 알겠습니다 감사합니다
#
# 저희 반품 기사가 방문할 주소지는 어디로 해드릴까요
#
# 집으로 해주세요 경기도 #@주소# 입니다
#
# 그 주소 제 핸드폰으로 좀 보내주세요
#
# 네 맞습니다 주소 한번 불러주시면 그쪽으로요
#
# 네 괜찮습니다 감사합니다 #@주소#입니다
#
# 그러시면 우선 주소 확인이 필요합니다
#
# 현재까지 주소 정정기간이니 다시 한번 고객님 주소 확인 부탁드립니다
#
# #@소속# 사이트에 등록되어 있는 주소로 보내주시면 될 것 같은데요
#
# 네 그러시면 회원 정보의 주소로 발송되실 거예요
#
# 그럼 메일 주소랑 휴대폰 번호만 입력하면 신청은 된 건가요
#
# 그래요 네 주소는 그럼 원래 구입했던대로요
#
# 네 주소지는 그대로 하고요
#
# #@주소#에서 진행중인 이벤트가 있나요
#
# 경품 응모시 회원정보의 자택 주소지로 배송되구요
#
# 이메일 발송 시 기본정보상에 입력하신 메일주소로 발송됩니다
#
# 아 제가 이메일 주소가 바뀌어서요
#
# #@주소#나 #@주소#역전에서 가능하십니다
#
# 별사탕 경품 배송은 당첨자 발표 후 주소 수정 기간을 두고 있어요
#
# 혹시 모르니 꼭 회원정보 내에 있는 주소 확인 부탁드릴게요
#
# 네 주소지는 동일하게 보내드리겠습니다 감사합니다
#
# 주소지 변경이 되나 싶어서요
#
# 네 주소지 변경 아직 가능하세요
#
# 그러면요 제가 친구네 집 주소 물어서요
#
# 네 그러면 주소지 그대로 보내드리겠습니다 감사합니다
#
# 당첨된 경품은 #@소속# 회원 정보란에 입력하신 주소지로 배송됩니다
#
# 주소지 입력 관련해서요
#
# 네 그러면 주소지 그대로 보내드리겠습니다 감사합니다
#
# 회원가입 시 입력하신 주소 연락처 비밀번호 메일주소는요
#
# #@전번# 예 주소는 어디로 보내드릴까요
#
# 서울 송파구 #@주소#
#
# 페이지 주소는 #@URL#입니다
#
# #@소속#계정은 이메일 주소의 주인 이외의 다른 사용자가요
#
# #@주소#에 매장 있죠
#
# 주소 입력을 했는데 우편번호가 달라서요
#
# 다른 주소로 주문 부탁드릴게요
#
# 가입 시 기재하셨던 이메일 주소를 입력합니다
#
# 여기서 주소 수정하면 결제한 건 배송지도 바뀌나요
#
# 맞아요 주소를 #@주소#로 변경 좀 해주세요
#
# 배송지 리스트에서 주소 수정하면 되나요
#
# 네 그렇습니다 기본 배송지로 설정할 주소 수정하시면 돼요
#
# 홀수 달 신청 기간 내 주소 확인해주시면 제공받으실 수 있습니다
#
# 저 혹시 홈페이지 주소가 변경됐나요
#
# 주소는 혹시 어떻게 되세요 고객님
#
# 지금 주소 변경 안 돼있을 건데요
#
# 전에 주소가 #@주소#로 돼있었거든요
#
# 대표 메일 주소가 어떻게 되나요
#
# 주소는 #@계정#이고요 관련 내용과 사진 함께 첨부해주세요
#
# 이메일 주소하고 휴대폰 번호가 바뀌어서요 어떻게 해야 하나요
#
# 홀수 달 신청 기간 내 주소 확인 시 히치하이커를 제공받으십니다
#
# #@소속#에서는 회원정보에 등록되어 있는 이메일 주소로요
#
# 많다 보니 다른 고객님께서 실수로 메일주소를 잘못 입력하여서요
#
# 제가 연결 주소 안내해드리겠습니다
#
# 네 주소 부탁드려요
#
# 변경된 주소는 #@URL#입니다
#
# 주소 변경은 어떻게 하나요
#
# 변경하실 주소 말씀해 주세요
#
# 네 #@주소#로 변경 부탁드려요
#
# 주소가 입력이 되잖아요
#
# 네 고객님 혹시 주소 찾기가 안되시나요
#
# 주소 변경은 어떻게 하나요
#
# 나의 이메일 가리기를 선택했는데 가입한 이메일 주소를 확인할 수 있나요
#
# 저 등록해둔 이메일 주소를 바꾸고 싶은데요
#
# 이메일 주소는 회원정보 수정에서 변경하실 수 있습니다
#
# 저 #@주소#에 있는 매장 정확한 위치가 어떻게 돼요
#
# #@주소# 매장이요 잠시만요 고객님
#
# 주소 검색 불가라고 나와서요
#
# 주소 검색이 안 되시는 경우 저희가 도와드리기 어렵습니다
#
# 다른 주소로 주문 부탁드릴게요
#
# 등록한 이메일 주소가 틀리다고 나와요
#
# 이메일 주소가 틀릴 경우 재설정 인증코드를 받을 수 없습니다
#
# 회원님의 이름과 가입 시 기재한 이메일 주소가 필요합니다
#
# 네 저 등록된 주소지를 좀 바꾸고 싶은데요
#
# 주소지는 회원정보를 수정해 주시면 됩니다
#
# 저희 #@주소#인데 되나요
#
# 주소창에 인터넷 #@소속# 주소를 직접 입력하신 후 다시 로그인 하시면 됩니다
#
# 고객님 이메일 주소로 견적서 발송해드리고 있습니다
#
# 아니요 등록된 메일주소나 휴대폰 번호를 통해 안내를 드립니다
#
# 휴대전화 주소지 변경할 경우 자주 쓰는 배송지에서도 수정이 필요합니다
#
# 네 여기에 배송받을 주소 입력하면 되나요
#
# 홈페이지 주소 좀 알려주세요
#
# 그러신가요 그럼 제가 문자로 주소 보내드릴까요
#
# 그거 구매하려는 접속 주소를 몰라서요
#
# 제가 지금 문자로 주소 링크 보내드릴게요
#
# 그래요 그럼 온라인 주소 좀 알려주세요
#
# 맞습니다 거기서 회사 이메일 주소와 비밀번호 입력하시면 됩니다
#
# 고객님 이메일 주소로 발송해 드리고 있습니다
#
# 일단 보이스피싱일 가능성이 있으니 주소는 클릭하지 마시길 바랍니다
#
# 이메일 주소가 바뀌어서 변경하려고 하거든요
#
# 예전에 #@주소#에서 서비스 받으셨나요
#
# 아니면 제가 주민등록증 볼게요 #@주소#네요
#
# 그럼 주소 알려주세요
#
# 저희 홈페이지 주소는 #@URL#입니다
#
# 크롬 주소창에 영어로 크롬 따움표 슬레시
#
# 그럼 그 주소는 문자로 보내주세요
#
# #@소속# 계정에 가입시입력하신 이메일주소가 계정 아이디가 되세요
#
# 고객님 이메일 주소 알려주시면 제가 보내드릴게요
#
# 사본은 사진 찍어서 보낼거고 이메일 주소는 어디로 보내요
#
# 개인 정보 및 배송지 주소 관리와 위시리스트 저장이 가능합니다
#
# 주소랑 연락처 변경 하려고요
#
# 변경된 연락처와 주소 부탁 드릴게요
#
# #@전번#으로 바뀌었고요 #@주소#에요
#
# 주소 좀 수정하고 싶어 가지고 전화드렸어요
#
# 그러면 주소 불러 주시겠어요
#
# 여기 주소가 #@주소#에요
#
# 혹시 모르니까 문자에 첨부된 주소같은거는 누르지 않으셔야 합니다
#
# 주문자 확인을 위한 이메일주소와 비밀번호만 입력하시구요
#
# 알겠습니다 그럼 이메일 주소 좀 가르쳐 주시겠어요
#
# 직접 가려고 하는데 회사 주소 좀 안내해 주세요
#
# 예 여기는 서울특별시 구로구 #@주소#입니다
#
# 회원가입하는데 이미 등록된 이메일주소래요
#
# 회원가입 시 이메일주소가 중복된다고 나오세요
#
# 가입자가 많아 다른 회원이 메일주소를 잘못 입력하신 경우가 있습니다
#
# 메일주소를 불러 주시면 고객님 계정으로만 등록 도와 드리겠습니다
#
# 예 제가 주문을 완료했는데요 주소지 변경이 가능한가요
#
# 배송상태가 결제완료 시점이면 주소 변경 요청이 가능합니다
#
# 주소지 변경은 불가합니다 고객님
#
# 그래요 그럼 주소지 변경이 안 되겠네요
#
# 제가 문자로 #@URL#과 메일 주소 보내드릴게요
#
# 이메일 주소로 임시 비밀번호를 발급해드립니다
#
# 한 사람이 여러개의 이메일 주소로 가입할 수 있나요
#
# 네 여러개의 이메일 주소로 각각 다른 계정을 만들 수 있습니다
#
# 그러나 각 이메일 주소는 서로 다른 계정으로 간주됩니다
#
# 비밀번호 입력 후 휴대폰 번호 이메일 주소 등의 정보 변경 가능합니다
#
# 주소를 예전 주소로 적었네요
#
# 네 여기서 주소 바꾸면 되나요
#
# 이메일이요 메일 주소 좀 알려주실래요
#
# 그냥 주소 하나만 바꾸려고 합니다
#
# 구매 시에 입력한 이메일 주소로 관련 메일이 발송됩니다
#
# 저 이메일 주소를 변경하고 싶은데 어떻게 해야 되나요
#
# 이메일 주소 변경이요
#
# 가입할 때 등록했던 이메일 주소 기억하세요
#
# 해당 주소로 비밀번호 재설정 링크 보내드립니다
#
# 네 주소를 바꾸려고 합니다
#
# 네 정보 변경으로 들어가시면 메일 주소 변경 가능합니다
#
# 예 이메일 주소 변경 가능한가요
#
# 고객님 아이디와 메일 주소 말씀헤주시겠어요
#
# 변경하시려는 메일 주소가 #@계정#인가요
#
# 예 주문번호와 입력하신 이메일 주소로 조회가 가능합니다
#
# 그러십니까 고객님 그러면요 제가 다른 주소 하나 보내드릴텐데요
#
# 웹주소 말씀하시는 건가요 어디로 보내주시는데요
#
# 네 #@계정# 메일로 저희 홈페이지 다른 주소 보내드리겠습니다
#
# 네 고객님 그 주소를 이용해주시고 안 되시면 다시 연락주세요
#
# 네 제 배송 주소 변경하려고요
#
# 거기서 원하시는 주소로 변경하시면 됩니다
#
# 메일 주소가 수신 차단되어 있지 않은 지 확인해 주시기 바랍니다
#
# 그러시면 마이페이지에서 회원정보수정에서 이메일 주소를 변경하시면요
#
# 네 구매하면 내용 오는 메일 주소 바꾸려고요
#
# 네 메일주소 #@계정#으로 바꿔주세요
#
# 이메일 주소 변경하고 싶은데요
#
# 제가 이사를 가서 주소를 변경 해야 하거든요
#
# 이메일 주소를 적으라고 해서 적었는데 안돼요
#
# 주소지 검색이 안 됩니다
#
# 네 주소지 검색이 안 되신다고요
#
# 행정자치부 시스템에서 주소지 확인이 가능합니다
#
# 동일하게 입력해도 주소지가 안 나와요
#
# 고객님 혹시 사용하시는 이메일 주소 좀 알 수 있을까요
#
# 혹시 홈페이지 주소를 알 수 있나요
#
# #@기타#의 홈페이지 주소는 #@URL#입니다
#
# 수고하십니다 #@소속# 주소 좀 알려주세요
#
# 네 고객님 #@소속# 온라인 주소 말씀이신가요
#
# 예 그거 구매 할 수 있는 주소 보내주세요
#
# 안양 #@주소# 확인되고 있는데요
#
# 신청은 #@기타# 주소로 하시면 됩니다
#
# #@주소# 여기로 배송되게 바꿔주세요
#
# 네 기본 배송지 #@주소#로 변경해드렸습니다
#
# 주소 변경은 어떻게 하나요
#
# 주소 좀 변경하려고요 #@주소#로요
#
# 기본 배송지 #@주소#로 변경해 드렸습니다
#
# 이메일 주소가 맞는데 비밀번호 재설정 인증코드가 도착하질 않네요
#
# 현재 이메일주소와 인증문자를 받을 수 있는 번호가 있으면 가능합니다
#
# 기존에 #@소속# 계정에서 이용중이던 이메일 주소를요
#
# 탈퇴한 후에 동일한 이메일 주소로 재가입이 가능한가요
#
# #@소속#계정을 탈퇴한 후 동일한 이메일 주소로 #@소속#계정에 재가입이 가능합니다
#
# 동일한 이메일 주소로 재가입을 하시더라도 새로운 식별코드가 부여된 신규 가입자로 간주됩니다
#
# 입점 제휴 대량 구매라고 이메일 주소가 있습니다
#
# 모바일 쿠폰북에 보니까요 저번에 #@주소#등록을 했더라구요
#
# 성함과 연락처 메일 주소 알려주시겠어요
#
# 고객님의 이메일 주소를 알려주시면 민원처리 신청서를 보내드릴게요
#
# 그러면 사이트 주소가 어떻게 돼요
#
# 저번 달에 주소가 변경되었거든요
#
# 혹시 수신 이메일 주소를 알 수 있을까요
#
# 회원정보에서는 이름 아이디 휴대폰번호 비밀번호 주소록 배송지를요
#
# 홀수 달 신청 기간 내 주소 확인해주시면 제공받으실 수 있습니다
#
# 아니오 주문하실 때 입력한 이메일 주소로도 안내를 해 드리거든요
#
# 뭐라구요 주소 다시 불러주세요
#
# 그냥 쇼핑몰 주소구나 알겠어요 수고하세요
#
# 메일 주소가 수신 차단되어 있지 않은 지 확인해 주시기 바랍니다
#
# 주소를 바꾸려고 하는데 회원 정보 수정은 어디서 하나요
#
# 두 번째는 주소 입력에 아이콘을 클릭하고요
#
# 또 쇼핑하실 때마다 번거롭게 주소 및 정보 입력을 안 하셔도 됩니다
#
# 어 전화 연결이 어려울 경우는 문자로 메일 주소 하나 남겨드릴게요
#
# 제가 얼마 전에 이사를 해서 상품을 받을 주소변경을 해야 하거든요
#
# 여기 사이트 말고 강제 설치가 가능한가요 주소 알려 주세요
#
# 혹시 홈페이지 주소도 알려주실 수 있나요
#
# 네 #@소속# 홈페이지 주소는 #@URL#입니다
#
# 메일 주소가 수신 차단되어 있는지도 확인해주세요
#
# 근데 #@이름#으로 돼 있고 주소 같은 거는 안 떠 있구요
#
# 나머지는 이제 회사 주소나 집 주소 같은 것도 없고 그러거던요
#
# 그러면 그쪽 주소 안내 부탁드립니다
#
# 강원도 홍천군 #@주소#입니다 이쪽으로 찍고 가시면 됩니다
#
# #@주소#이요 예 알겠습니다
#
# #@소속#이요 주소 알려주세요
#
# 네 주소 안내해드리겠습니다
#
# 종합사격장 주소는 충북 청주시 서원구 #@주소# 입니다 고객님
#
# #@주소# 쪽으로 가게 될 것 같아요
#
# #@주소#이시면 채계산과 가까운데요 채계산 등산 어떠세요
#
# 진해루해변공원으로 가시면 되는데요 주소를 불러드릴까요
#
# 네 네비 찍고 갈건데 주소 알려주세요
#
# 네 창원시 진해루 #@주소# 입니다 고객님
#
# 네 #@주소#이요 감사합니다
#
# 괜찮습니다 #@이름# 님 이메일 주소 불러 주시겠어요
#
# 거기 주소가 어떻게 되지요
#
# 저희 승마 클럽 주소는 경기 김포시 #@주소#입니다
#
# 장소는 #@주소#입니다 고객님
#
# 주소 검색하시면 바로 나올 거예요
#
# 담양군 #@주소#에 위치해 있습니다
#
# 경기도 양평군 #@주소# #@기타#입니다
#
# 혹시 주소를 알려 주실 수 있나요
#
# 주소는 강원도 삼척시 #@주소#입니다
#
# #@주소# 근처에 라이딩하기 좋은 곳 없을까요
#
# 고객님 #@주소#에 보청천 자전거길이 있는데요
#
# 그래요 #@소속# 거기 주소 좀 알려 주세요
#
# 불러 드릴게요 파주시 #@주소#입니다
#
# 네 가평군 설악면 #@주소#에 위치하고 있습니다
#
# 홈페이지 주소 좀 알려 주세요
#
# 홈페이지 주소나 SNS 주소 알려드릴까요
#
# 주소는 #@계정#으로 가시면 되세요
#
# 정확한 주소가 어떻게 될까요
#
# 도로명 주소이고 #@주소# 치시면 나오세요
#
# 네 주소 좀 알려주시겠어요
#
# 레포츠샵 사이트에서 해주시면 되는데 주소 안내해드리겠습니다
#
# 레포츠샵 홈페이지 주소는 #@URL# 입니다
#
# 네 위치는 경기도 군포시 #@주소# 입니다
#
# 네 그리고 저 주소 좀 알려주세요
#
# 네 주소는요 창원시 의창구 #@주소# 입니다
#
# 네 주소 적었습니다 감사해요
#
# 네 고객님 메일 주소를 불러주시겠어요
#
# 네 제 메일 주소는요 #@계정#입니다
#
# 네 상호명 쳤는데 안 나와서요 주소 좀 알려 주세요
#
# 제주특별자치도 제주시 #@주소#입니다
#
# 감사합니다 주소 쳐 보고 안 되면 다시 연락드려도 되죠
#
# 아 그래요 홈페이지 주소 좀 알려주시겠어요
#
# 네 주소 불러드리겠습니다 #@URL# 입니다
#
# 저 #@주소# 마을 어촌 체험 때문에 연락 드렸는데요
#
# 네 #@주소# 말씀이신 거죠
#
# 팔봉산 가려고 하는 데 주소 좀 불러주실 수 있나요
#
# 강원도 홍천군 #@주소# 입니다 입력 되셨을까요
#
# 담양군 #@주소#에 위치해 있습니다
#
# 네 양양군에 주소를 둔 개인의 경우 평일은 사용료의 50프로가 할인 되세요
#
# 담양군 #@주소# 검색하시면 되구요
#
# 거기 골프장 가려고 하는데요 주소 안내 좀 부탁해요
#
# #@소속# 골프장은 삼척시 #@주소#에 위치하고 있습니다
#
# 정확히 삼척시 #@주소# 맞습니까
#
# #@주소#로 찍으시면 주차장 있는 쪽으로 가실 수 있습니다
#
# #@주소# 종합 경기장 내에 있습니다
#
# 네 가평군 상면 #@주소# 입니다
#
# 주소 불러주실 수 있을까요 길을 잘 못 찾아서요
#
# 강원도 홍천군 #@주소#입니다 입력 하셨을까요
#
# 그럼 시민 확인은 주소로 확인하시나요
#
# 네 주민등록증에 나와 있는 주소로 확인합니다
#
# 금은모래 캠핑장 바로 옆인데요 여주시 #@주소#입니다
#
# 네 알겠습니다 저 주소도 좀 알려주시겠어요
#
# 네 주소 불러드리겠습니다 충북 제천시 #@주소#입니다
#
# 네 주소 적었어요 상담 감사해요
#
# 네 경북 청도군 #@주소# 입니다
#
# 장소는 경기도 양평군 #@주소#으로 나오네요
#
# 음 그렇군요 주소 알려주세요
#
# 네 사격체험장 주소는 창원시 의창구 #@주소#입니다
#
# 정확한 주소 좀 알려 주세요
#
# 대전광역시 유성구 #@주소#입니다
#
# 네 그렇습니다 주소 안내 드릴까요
#
# 네 고객님 당진시 #@주소#입니다
#
# 그래요 홈페이지 주소 좀 알려주실 수 있어요
#
# 네 홈페이지 주소 불러드릴까요
#
# 저희 홈페이지 주소는요 #@URL# 입니다
#
# 네 주소가 #@URL# 맞나요
#
# 네 맞습니다 알려드린 주소로 접속하셔서 예약해주시면 돼요
#
# 주소를 좀 알려주시겠어요
#
# 네 종합사격장 주소 안내해드리겠습니다
#
# 주소는요 충북 청주시 #@주소# 입니다 고객님
#
# 혹시 홈페이지 주소를 알 수 있을까요
#
# 네 강원도 홍천군 #@주소# 입니다 되셨을까요
#
# 그럼 그냥 주차장 주소를 알려주시겠어요
#
# 예 주차장 주소는 순창군 #@주소#입니다
#
# 네 주소를 알려드리면 될까요
#
# 네 공주시 #@주소# 입니다
#
# 대구 #@주소# 쪽에 초등 아이 승마체험 가능한 곳이 있나요
#
# 충북 보은군 #@주소#에 있구요 겨울철 빙어낚시로 유명합니다
#
# 주소를 잘못 찍은 거 같은데 주소 좀 불러주실래요
#
# 네 경남 거제시 #@주소# 입니다 입력 되셨을까요
#
# 혹시 도로명 말고 옛 주소로 불러주실 수 있나요
#
# #@주소# 로 검색하시면 될 거예요
#
# #@주소#으로 가서 접수하면 되는 거죠
#
# 정선군 #@주소#로 검색하시면 됩니다
#
# 네 네비가 되시면 광주 서구 #@주소# 네비 찍고 오시면 됩니다
#
# 광주 서구 #@주소# 여기 맞나요
#
# 네 맞습니다 그 주소로 오시면 #@소속#이 보이실 겁니다
#
# #@URL# 주소 이거 맞나요
#
# 그렇군요 아이들이랑 같이 가기 좋겠다 저기 주소 좀 알려주세요
#
# 네 주소 안내해드리겠습니다
#
# 옥순정국궁정 주소는요 제천시 수산면 #@주소# 입니다 고객님
#
# 죄송하지만 상세한 주소 한 번만 불러주세요 길을 못 찾아서요
#
# 네 알겠습니다 #@주소#입니다
#
# 사이트에서 해주시면 되는데 주소 안내해드릴까요
#
# 네 사이트 주소는 #@URL# 입니다 고객님
#
# 메일 주소가 바뀌었어요 #@계정#으로 보내 주세요
#
# 네 사곡면 #@주소#에 있는 산 안에 있습니다
#
# 자세한 주소를 알 수 있을까요
#
# 네 사곡면 #@주소#입니다
#
# 저기 그럼 #@기타# 주소 좀 알려주실 수 있어요
#
# 네 주소 불러드려도 될까요
#
# 네 창원시 의창구 #@주소# 입니다 고객님
#
# 창원시 의창구 #@주소#이요 적었어요 감사합니다
#
# 혹시 주소 알려주실 수 있나요
#
# 네 전남 해남군 #@주소#입니다
#
# 혹시 주소지가 함안군 이실까요
#
# 광주 상무지구 #@주소#에 위치해 있습니다
#
# 혹시 주소나 전화번호 알 수 있을까요
#
# 전화번호는 #@전번#이고 주소는 여주시 #@주소#입니다
#
# 네 받으실 분 성함과 연락처 주소 말씀해 주시겠습니까
#
# 네 주소는 어떻게 되실까요
#
# 네 주소 가요 #@주소#입니다
#
# 네 고객님 음성읍 #@주소#에 #@기타#이 있는데요
#
# 네 주소가 어떻게 된다고요
#
# 네 고객님 #@기타# 주소는요 충북시  #@주소# 입니다
#
# 네 주소 적었어요 #@기타#를 해보고 싶은데 미리 예약해야 되죠
#
# #@주소# 해수욕장 머드 광장에서 진행되고 있습니다
#
# #@주소#부터 #@주소# 앞까지입니다
#
# 네 맞습니다 저희 주소도 #@주소#에 해당되구요
#
# 네 이곳 주소는요 #@주소#입니다
#
# 인터넷 카페가 따로 있군요 주소 좀 한번 알려주시겠어요
#
# 네 시민 할인은 #@주소# #@주소# 가능하세요
#
# 위치는 울릉군 #@주소#입니다
#
# 강원도 홍천군 #@주소# 으로 가시면 됩니다
#
# 주소 말씀해 주시면 찾아갈 수 있을 것 같아요
#
# 예 순창에 있는 승마장 주소 알려드릴게요
#
# 순창군 #@주소#로 찾아주시면 됩니다
#
# 예 주소 지금 적었어요 제가 검색해 볼게요
#
# 보통 장릉산은 사우약수터 천주교 #@주소# 코스로 등산하세요
#
# 승마센터이요 주소 알려주세요
#
# 했는데 주소를 제가 못 찾겠어서요 위치 주소 좀 불러주세요
#
# 네 보성군 #@주소#로 찾아서 오시면 됩니다
#
# #@주소#이요 여기 맞죠
#
# 네 #@주소# 맞습니다
#
# 좌구산 자연휴양림이요 주소 좀 알려주시겠어요
#
# 네 주소 안내해드리겠습니다 충북 증평군 #@주소# 입니다
#
# 인사동점은 탑골공원 옆 어학원 건물인 #@주소#에 있습니다
#
# #@소속# 사이트요 주소 좀 알려주시겠어요
#
# 네 사이트 주소는 #@URL# 입니다
#
# 강원도 동해시 #@주소# #@소속#로 오시면 됩니다
#
# 불러 드리겠습니다 경북 울릉군 #@주소#입니다
#
# #@소속#는 점동면 #@주소#에 있습니다
#
# #@소속# 쳤는데도 지금 안 나와요 주소 없나요
#
# 아 네 그럼 주소 알려드릴게요 제주시 #@주소# 입니다
#
# 제주시 #@주소# 여기 맞나요
#
# #@주소#에 등산하는 코스가 있던데 안내받을 수 있나요
#
# #@주소#에서 #@소속#입구를 지나 북측 순환로 입구까지 가십니다
#
# 네 거기에서 쭉 #@주소# 쪽 쉼터를 지나서 북측 순환로 버스정류장을 지나시고요
#
# 정말요 다행이네요 위치는 #@주소# 맞나요
#
# 네 알겠습니다 저 그리고 주소 좀 알려주실 수 있나요
#
# 네 명암저수지 주소 안내해드리겠습니다
#
# 고객님 주소 불러드릴게요 충청북도 제천시 봉양읍 #@주소# 입니다
#
# 네 #@주소#이요 추천 감사합니다
#
# 아 네 그럼 사이트 주소 좀 말씀해 주세요
#
# 거기 정확한 주소 지금 좀 불러 주세요
#
# 정선군 #@주소# 찾으시면 됩니다
#
# 그래요 주소 좀 정확하게 알려주시겠어요
#
# 네 주소 불러드리겠습니다 충북 단양군 #@주소#입니다
#
# 예 #@주소#에 있는 채계산 말씀하시는 것 같네요
#
# 천불산 등산 예정인데 주소를 어디로 찍고 가야 하나요
#
# 강원도 #@주소#로 찍고 오시면 됩니다
#
# 네 홈페이지 주소를 문자로 보내주실 수 있나요
#
# 네 가능합니다 #@주소#에 위치하고 있습니다
#
# 위치는 만성역 근처인데 주소 안내 도와드릴까요
#
# 전남 여수시 #@주소#이라고 치시면 됩니다
#
# 그럼 지번 주소 알려 드릴게요 여수시 #@주소#입니다
#
# 네 이제 주소가 나오네요 친절하게 안내해 주셔서 감사해요
#
# 고객님 안내 받으실 이메일 주소 알려 주시겠어요
#
# 주말에 가 보려고 하는데 주소 좀 알려 주세요
#
# 승마장 주소는 #@주소#입니다
#
# 홈페이지 주소 알려주세요
#
# 네 주소 불러드리겠습니다 #@URL# 입니다 고객님
#
# 네 감사합니다 마지막으로 거기 주소 좀 알려주세요
#
# 네 낚시터 주소 불러드리겠습니다
#
# 충북 충주시 노은면 #@주소# 입니다 고객님
#
# 혹시 주소를 알려드려도 괜찮으실까요
#
# 예 주소 좀 불러주세요
#
# 말씀 드릴게요 순창군 #@주소#에 있습니다
#
# 혹시 주소 알려주실 수 있나요
#
# #@주소#에서 수상 레저를 이용할 수 있나요
#
# #@주소#에 어린이 썰매장이 생겼다고 하는데 맞나요
#
# 네 #@주소#에서 무료로 썰매장을 개방하였습니다
#
# 네 경기도 용인시 #@주소# 입니다
#
# 울릉군 #@주소#입니다 잘 적으셨을까요
#
# 정선군 #@주소# 검색하시면 됩니다
#
# 죄송한데 정확한 주소를 불러 주실 수 있을까요
#
# 네 저희 주소는 #@주소# 입니다
#
# 잠시만요 #@주소# 주소가 맞나요
#
# 네 고객님 #@주소#으로 전화하시면 됩니다
#
# 혹시 눈썰매장 주소도 알 수 있을까요
#
# 네 주소는 서울시 구로구 #@주소#입니다
#
# #@주소#에 있는 #@소속# 안내해 드리겠습니다
#
# 강원도 삼척시 #@주소#입니다
#
# 그럼 #@주소#와 #@소속# 낚시터를 추천 드리고 싶네요
#
# #@주소#와 #@소속# 낚시터요
#
# #@주소#는 30분 정도 #@소속#는 40분 정도 소요되구요
#
# 당진시 석문면 #@주소#입니다
#
# 담양군 #@주소#에 위치해 있습니다
#
# 네 고객님 여주시 #@주소#입니다
#
# 담양군 #@주소#에 자리 잡고 있습니다
#
# 죄송한데 정확한 주소 좀 알려주시겠어요
#
# 네 불러드릴게요 #@주소# 여기입니다
#
# 주소 안내해 드리면 될까요
#
# 네 주소 알려주세요
#
# 네 주소 불러드리겠습니다 제천시  #@주소# 입니다 고객님
#
# 네비에 찍을 주소 좀 정확히 알려 주시겠어요
#
# 정선군 #@주소# 검색하고 방문하시면 됩니다
#
# 그렇군요 주말에 가보고 싶은데 주소가 어떻게 될까요
#
# 네 주소 안내해드리겠습니다
#
# 어드벤처 주소는 창원시 진해구 #@주소# 입니다
#
# 네 주소 적었습니다 상담 고맙습니다
#
# 영월군 #@주소#를 찍으시면 돼요
#
# #@소속#요 주소 좀 알려 주세요
#
# 네 주소 안내해 드리겠습니다 충북 단양군 #@주소#입니다
#
# 정확한 위치가 안나와서요 주소 좀 알려주세요
#
# 충청남도 논산시 #@주소# 입니다 입력 되셨을까요
#
# 홈페이지 주소 알려주세요
#
# 네 홈페이지 주소 불러드려도 될까요
#
# 아 네 #@URL# 이 주소 맞나요
#
# 주소 불러 드리겠습니다 #@주소#입니다
#
# 음 그렇군요 4구간 주소 알려주세요
#
# 4구간을 시작하는 합계마을 주소를 알려드리면 될까요
#
# 아 그렇군요 합계마을 주소로 알려주세요
#
# 네 주소 불러드리겠습니다 진해구 #@주소# 입니다
#
# 네 주소 안내 도와드리겠습니다
#
# 해양레포츠센터 주소는 부산시 사하구 #@주소# 입니다
#
# 네 부산시 사하구 #@주소#요 감사합니다
#
# 주소도 좀 알려주실래요
#
# 주소는 경상남도 하동군 #@주소#입니다
#
# 위치를 주소로 검색하시면 됩니다
#
# 그럼 자세한 주소 좀 알려 주시겠어요
#
# 주소가 경상북도 문경시 #@주소#입니다
#
# 예예 그 혹시 주소 좀 불러주실 수 있을까요
#
# 강원도 홍천군 #@주소# 입니다 다 받아적으셨을까요
#
# 네네 주소 찍었습니다
#
# 여주에 있는 #@소속#의 상세 주소와 번호좀 말씀해주세요
#
# #@소속#의 주소와 문의 번호 말씀이시죠
#
# 네 잠시만요 주소 불러드릴게요
#
# 적으시면 돼요 #@주소# 이구요
#
# 익스트림 루지요 주소 좀 알려주세요
#
# 네 고객님 주소는요 충청북도 증평군 도안면 #@주소# 입니다
#
# 네 주소 불러주시겠어요
#
# 첫 번째는 #@주소#으로부터 시작되는 오래된 등산로가 있고요
#
# 네 고객님 #@주소#입니다
#
# 혹시 모르니까 주소 좀 알려 주세요
#
# 네 여기 주소가요 #@주소#입니다
#
# 네 오후 6시까지요 그럼 거기 주소 알려주시겠어요
#
# 네 주소 안내해드리겠습니다
#
# #@소속# 주소는 창원시 진해구 #@주소#입니다
#
# 네 창원시 진해구 #@주소#요 알겠습니다 감사합니다
#
# 네 보문단지에서 가까운 #@주소#에서 ATV체험이 가능합니다
#
# 네 요즘 #@주소#과 #@주소#에서 이용 가능하세요
#
# 업체 주소를 알 수 있을까요
#
# 네 경주 레저 주소는 경주시  #@주소#입니다
#
# 네 골프장 주소 불러드리면 되나요
#
# 네 가평군 설악면 #@주소# 입니다
#
# #@소속#은 경주시 #@주소#에 있습니다
#
# 네 구안저수지요 주소 좀 알려주시겠어요
#
# 네 주소 안내해드리겠습니다 충청북도 음성군 #@주소# 입니다
#
# 네 주소 적었습니다 알려주셔서 감사합니다
#
# 그럼요 고객님 이메일 주소 말씀해 주세요
#
# 네비따라 오니까 다른 곳으로 왔는데 주소한번만 알려주시겠어요
#
# 네 알겠습니다 전라남도 해남군 #@주소# 입니다
#
# 네 충남 공주시 사곡면 #@주소# 입니다
#
# 네 알겠습니다 주소 좀 알려주실 수 있나요
#
# 네 주소는요 창원시 의창구 #@주소# 입니다
#
# 맹동저수지요 주소 좀 알려주세요
#
# 네 주소 불러드릴게요 충청북도 음성군 #@주소# 입니다
#
# 네 주소가 #@주소# 맞죠 아 네 감사합니다
#
# 대구 #@주소# #@소속# 추천드립니다
#
# 네 맞아요 거기 주소가 어떻게 되나요
#
# 보성군 #@주소#입니다
#
# 보성군 #@주소#이라고요
#
# #@주소#입니다 가셔서 모험시설 찾으시면 됩니다
#
# 전남 보성군 #@주소#입니다
#
# 주소 상으로는 경주시 #@주소#입니다
#
# 강촌 IC에서 가까운데요 자세한 주소를 알려 드릴까요
#
# 주소요 네 알려 주세요
#
# 네 낚시터 주소는 #@주소#입니다
#
# 아 주소 안내 드리면 될까요
#
# 네네 주소 불러주시겠어요
#
# 경상남도 거제시 #@주소# 입니다 받아적으셨을까요
#
# #@주소#요 네 네비 입력했습니다
#
# 네 주소 알려드릴까요
#
# 네 경상북도 청도군 #@주소#입니다
#
# 홈페이지 주소 좀 불러주실 수 있나요
#
# 네 주소 불러드리겠습니다 #@URL# 입니다
#
# 정말요 저도 빨리 가서 배워보고 싶은걸요 주소좀 알려주시겠어요
#
# #@주소#입니다
#
# 고객님 현재 주소지가 도서산간지역에 속하시거든요
#
# 그렇긴한데 다른 주소지랑 뭐가 다른가요
#
# 네 맞아요 주소지 변경 가능하지요
#
# 예 그럼 변경할 주소지 좀 불러 주시겠어요
#
# 울산시 남구 #@주소#로 할게요
#
# 예 #@주소#로 변경 도와드렸습니다 고객님
#
# 물건 주문했는데 배송지 주소 좀 변경하고 싶어서요
#
# 주소가 그렇게 되어 있으신데요
#
# 어디 무슨 주소요
#
# #@주소# 쪽으로 주소 되어 있는데요
#
# 네 그렇게 되어 있는데 #@주소#로 돼 있어요
#
# 마지막으로 받으실 주소지 입력 후 변경완료를 선택하시면 완료됩니다
#
# 확인 감사합니다 지금 #@주소#까지 기재되어 있으시구요
#
# 예 동 호수가 #@주소#입니다
#
# #@주소# 까지만 되어 계시는데요
#
# 제 나머지 주소는 #@주소# 입니다
#
# 나머지 주소가 #@주소# 라는 말씀이시죠
#
# 링크 주소는 문자로 발송해 드리겠습니다
#
# 네 받으실 주소지 말씀 부탁 드리겠습니다
#
# 경기도 하남시 #@주소#입니다
#
# 경기도 하남시 #@주소# 감사합니다 고객님
#
# 배송지 주소 변경을 하고 싶어요
#
# 변경할 주소가 어떻게 되나요
#
# 서울시 송파구 #@주소#로 변경해 주세요
#
# 말씀하신 주소로 변경되었습니다
#
# 고객님 발송 누락이 확인되었습니다 기존 주소로 다시 보내드리면 될까요
#
# 여기 안양시 #@주소# #@소속# 매장 있는데 가능한지 봐 주세요
#
# 배송지 입력을 하는데 옛날 집 주소로 된 거 같은데 어떡하죠
#
# 번거로우시더라도 배송된 주소지에서 제품을 수령해 주셔야 할거 같습니다
#
# 고객님 그러셨어요 혹시 배송지 주소를 잘못 입력하셨나요
#
# 네 배송지를 #@주소#로 입력 하셨는데 맞나요
#
# 아니요 이사 오기 전 주소네요
#
# 주소가 변경되셨어요 고객님
#
# 그래서 제가 게시판 링크 주소를 좀 문자로 보내 드릴 테니까요
#
# 제가 문자로 링크 주소 발송을 좀 해 드릴게요
#
# 네 이메일 주소가 이제이로 이렇게 되어 있는 거 말씀하시는 거예요
#
# 그러면 배송 주소지 오류로 반송되거나 하면요
#
# #@상품# 주문했는데 주소를 잘못 입력해서요
#
# 오늘 주문하신 #@상품# 확인되시구요 주소 변경 원하시는 걸까요
#
# 네 #@주소#가 아니고 #@주소#로 부탁드립니다
#
# #@주소#로 변경 해드렸구요 다른 문의사항 없으실까요
#
# 이사 가시는 주소가 #@주소#맞으시구요
#
# #@소속# 픽업을 선택하고 받으실 주소를 찾아주시면 됩니다
#
# 네 버튼 누르시면 바로 주소 찾는 화면으로 넘어 갑니다
#
# 제가 입금을 시키고 저희 주소를 보내드릴게요
#
# 그게요 제가 지인한테 들었는데 해외에서 주문이 가능한 쇼핑몰 주소가 따로 있다던데요
#
# 아니에요 혹시 해당 주소 좀 제 핸드폰 번호 #@전번# 이쪽으로 보내 주실 수 있을까요
#
# 네 알겠습니다 미국에서 주문 가능한 인터넷 주소 제가 통화 종료 후에 바로 보내 드릴게요
#
# 네 수고하세요 잠시만요 하나만 더요 제가 주소에요
#
# 아마 이게 도로명 주소에서는 그게 주소에 포함되어 있는 거라서요
#
# 아니요 이 주소대로 가실 거예요 #@주소# 아니세요
#
# 네 #@주소# 라는 게 빠져 있더라구요
#
# 도로명 주소 입력하면 아파트명 제외하고서 바로 입력이 되시더라구요
#
# 상품 준비중으로 넘어가면 주소변경은 어려우십니다
#
# 근데 배송 주소 입력을 실수했어요
#
# 배송된 주소에서 제품을 수령해 주세요
#
# 예 보통 거기에 같이 이제 송장 번호랑 주소랑 그러니까 고객님 남겨주신 게 있거든요
#
# 예 고객님 현재 거주하시는 곳 주소가 #@주소#라고 하셨구요
#
# 네 이사 가는 주소는 #@주소#요
#
# 전송자 주소가 지금 수정이 안 되서요 주소만 수정 해주세요
#
# 주소지가 그 수령 주소지가 경기 여주시 #@주소# 로 되어 있는데요
#
# 여기 주소를 그러면 어디로 변경을 해드릴까요
#
# 아 거기다가 #@주소# 만 넣어주시면 돼요
#
# 그러면은 경기 여주시 #@주소# 맞으시죠 #@주소# 죠
#
# 네 그 주소 맞아요
#
# 네 #@주소# 이렇게 넣어드렸습니다
#
# 상품이 이미 출고된 경우에는 주소지 변경이 어렵습니다
#
# 배송 후 주소지 변경은 고객님께서 직접 택배사를 통해 변경하셔야 합니다
#
# 네 고객님 주소 변경은 상품준비 전 상태까지는 가능합니다
#
# 네 고객님 현재 고객님 주소지가 제주도로 되어 있으신가요
#
# #@주소#에서 배달 지역으로 이동 중으로 있다고 나와 있거든요
#
# 네 #@전번# 이요 배송 주소는 어디로 보내드릴까요 고객님
#
# 어 #@주소# 으로 보내주시겠어요
#
# 네 #@주소# 까지 들었구요 단독이실까요 고객님
#
# 네 그럼 여기까지 #@주소# 까지 주소 놓겠습니다
#
# 근데 #@주소#까지만 적혀있어요
#
# 네 주소가 짧네요
#
# 음 잠시만요 고객님 그러면 고객님은 인천시 #@주소#  맞으시죠
#
# 네 근데 #@주소# 담당 이래요
#
# 주소지 전달 부탁 드립니다
#
# 경기도 성남시 #@주소#요
#
# 수령자 배송지 주소를 먼저 변경하고 싶어서요
#
# 현재 #@소속#에서 국내 모든 주소지로 배송을 진행하고 있습니다
#
# 배송 주소지 변경할 수 있나요
#
# 고객님 죄송하지만 제품 출고되어 주소지 변경이 불가합니다
#
# 답답하네 왜 주소지가 그쪽으로 나가냐고요
#
# 자꾸 물건을 보낼 때 #@주소#이 어디에요
#
# 예 저희가 #@주소# 근방 매장에서 구매 하려고요
#
# 그러시면 배송국가 확인과 주소 작성이 필요하신데요
#
# 받으실 주소 영문으로 입력 부탁드립니다
#
# 주문자 수령자 주소 연락처 남겨 주시면 출고해드리도록 하겠습니다
#
# 네 #@주소#로 바꿔주세요
#
# 예 제가 근데 주문한 곳 배송지 주소를 변경하려고요
#
# 네 저희가 이미 상품을 결제했는데요 주소랑 연락처를 바꾸려고요
#
# 주소에 아파트 이름이 안 들어갔었거든요
#
# 네 맞아요 주소 좀 확인 해 주세요
#
# 도로명 주소로 입력되면 원래 아파트 이름은 따로 들어가지 않습니다
#
# 고객님 아파트 #@주소# 맞으시죠
#
# 네 주소 잘 입력되셨으니 잘 배송 될 겁니다
#
# 마이페이지 주소록관리에서 변경해 주세요
#
# 제가 주문을 했는데 주소가 잘못돼서 전화드렸습니다
#
# 주소 잘못되셨다고 말씀해 주시는 거 맞으신가요
#
# 네 주소 변경하려구요
#
# 맞아요 #@주소# 로 바꿔 주세요
#
# 제품을 배송받으시는 주소지가 다른 경우에는요
#
# 지금 배송 주소 변경 가능한가요
#
# 네 고객님 받으시는 주소 말씀이시죠
#
# 네 조금 전에 구매했는데 주소를 바꾸려고요
#
# 상품 출고 전에는 배송지 변경 가능하세요 주소 말씀해 주세요
#
# 네 주소를 #@주소#로 바꿔 주세요
#
# 주소를 입력할 때 다른 배송지를 입력할 수 있습니다
#
# 예 #@이름# 배달지는 #@주소# #@전번# 이요
#
# 배송지 주소를 바꾸려고 하는데요
#
# 현재 출고가 진행 중이어서 직접 주소 변경이 어려우시거든요
#
# 습관적으로 이전에 살던 집 주소를 입력해 버렸어요
#
# 저 배송 주소 변경 가능한가요
#
# 네 변경하실 주소 알려주시겠어요
#
# 네 경기도 고양시 #@주소#입니다 받는 사람이랑 연락처는 그대로요
#
# 네 고양시 #@주소# 변경했습니다 고객님
#
# 주소를 변경했는데 이전 주소로 배송이 되서요 어떻게 해야 하나요
#
# 모바일앱 사용시 내정보관리 주소록관리에서 가능합니다
#
# 기다려 주셔서 감사합니다 고객님 주소지 #@주소# 맞으세요
#
# 네 고객님 받으시는 주소 어떻게 되실까요
#
# 여기 주소가 경남 밀양시 #@주소#입니다
#
# 주소가 잘못됐는지 확인하려고 전화드렸습니다
#
# 수령 주소지가 부산 #@주소#로 되어있는데 틀리셨다는 말씀이신가요
#
# 토요일 수령가능한 주소지로 주문해주시는 게 좋을 것 같아요
#
# 늦더라도 직접 수령이 가능한 주소지가 좋으실 거예요
#
# 고객님 상품 수령지 주소가 #@주소# 로 되어 있습니다
#
# 예 주소는 맞네요
#
# 한 번에 결제했는데 주소지 다르게 보낼 수 있나요
#
# 네 #@이름# #@전번#이고요 경기도 수원시 #@주소#로 적었는데요
#
# 확인 되셨습니다 변경 주소지는 어떻게 될까요
#
# 경기도 수원시 #@주소#로 변경해 주세요
#
# 네 고객님 구매 이력 있으신대 #@주소#로 보내드릴까요
#
# 네 그 주소로 보내주시면 됩니다 감사해요
#
# 영문 이름 주소 국가 국번 포함한 연락처는 필수 기재하시고요
#
# 네 그래서 반품 시키려면 주소가 있어야 할텐데
#
# 배송 중으로 떴는데 수령주소지 변경이 가능한가요
#
# 주소지 변경은 주문 후 익일 오전 열한 시 이전까지만 가능합니다
#
# 취소가 아니라 주소 변경을 원하시는 거면요
#
# 아까 전화 주셔서 주소지 잘 못 입력하셔서 배송 잘 못되셨다구요
#
# 네 지금 다 #@주소# 로 돼 있어서 아마 기사님 연락 오시면요
#
# 혹시 이거 기사님 통화하셔가지고 #@주소#로 보내달라고 해주세요
#
# 연락을 서로 이거 주소지가 잘못됐어도 서로가 연락이나 하는데요
#
# #@소속#에서 배송 가능한 모든 주소지가 가능합니다
#
# 해 봤는데 다른 주소지로 전달됐다고 하더라고요
#
# 주소가 잘못 돼 가지구요
#
# 어 지금 수령하신 주소 보니까
#
# 경주 경기 여주시 #@주소# 로 확인되시는데요
#
# #@주소# 인데 #@주소# 로다가 잘못 들어간 거지 그러면요
#
# 근데 #@주소# 로 기사님은 그쪽으로 이제 배송을 하셨단 말씀이신 거죠
#
# #@주소# 쪽은 이제 확인이 어렵다 보니까 못 하셨다는 말씀이신 거죠
#
# 제가 #@주소#로 받아야 되는데
#
# #@주소#에서 배달 지역으로 이동 중으로 있다고 나와 있거든요
#
# 다른 건 아니고요 주소를 좀 변경하고 싶은데 가능한가요
#
# 메일 주소는 #@계정#입니다
#
# 배송 주소는 어디로 보내드릴까요
#
# 음 광주 광역시 #@주소# 여기로요
#
# 혹시 받는 주소지를 집으로 하셨었나요
#
# 네 주소지 변경은 어떻게 하나요
#
# 배송지 주소는 주문 진행 상태에 따라 변경 방법이 상이합니다
#
# 두 건 상품 중 어떤 제품 주소지 변경이신가요
#
# 네 고객님 받아보실 주소지는 어떻게 되십니까
#
# 네 여수시 #@주소# 입니다
#
# 영문으로해외 배송지 주소 및 해외 연락처 기재해 주시면 됩니다
#
# 네 고객님 저희 화성 #@주소#에서 픽업 가능합니다
#
# 화성 #@주소# 네 알겠습니다
#
# 제가 아침에 주문을 했는데 주소 변경할 수 있나요
#
# 고객님 수령 주소지 #@주소#로 되어있는데 변경 도와드릴까요
#
# 네 #@주소#로 바꿔주세요
#
# 고객님 #@주소#로 변경해드렸습니다
#
# 배송조회에서 비밀번호와 입력한 이메일 주소로 확인하실 수 있습니다
#
# 이거 구월 이십사 일 배달 완료 #@주소#로 돼 있으셔서요
#
# 주소지를 확인해드릴게요 잘못 배송이 된 경우거든요
#
# 네 주소지가 #@주소#아닌가요
#
# 그래요 이사하기 전 주소로 보냈나봐요
#
# 배송 전 주문자 주소 전화번호 일치할 경우 문의하세요
#
# 주소 확인을 한번 해달라고 하시더라고요
#
# #@상품# 주문하신 곳 주소 말씀이세요
#
# 예 수령지 주소가 경기 성남시#@주소# 입니다
#
# 예전 주소지로 한 것 같은데 어떻게 수정해야 하죠
#
# 현재 고객님 주소지 배송 담당자가 픽업했습니다
#
# 네 제 이름은 #@이름# 이구요 #@주소# 예요
#
# 제가 주소지가 시골이라 배송비가 추가되는지 좀 여쭤보고 싶어서요
#
# 네 고객님 주소가 어떻게 되시나요
#
# 네 저희 집 주소는 #@주소# 입니다
#
# 네 고객님 확인해보니 추가 배송비가 발생하는 주소지이시네요
#
# 예 저 배송 받을 주소를 바꾸고 싶어요
#
# 네 배송 받으실 주소가 바뀌셨습니까
#
# 네 담당자가 확인했다면 바뀐 주소로 배송될 겁니다
#
# 고객님 확인해보니 배송 받으실 주소 #@주소# 맞으신가요
#
# 그럼 주소를 영어로 쓰면 되나요
#
# 회사 주소지로도 총알배송은 가능합니다
#
# 오후 늦게라도 상품수령이 가능한 주소를 입력해주세요
#
# #@주소#인데 얼마나 걸려요
#
# 그런데 여러 주소로 보내고 싶어서요
#
# 여러 주소로 배송을 받으셔야 합니까
#
# 그럴 때는 주소별로 각각 주문해 주셔야 합니다
#
# 네 주문 한 건당 하나의 주소지만 등록 가능합니다
#
# 지금 주소지가 대구이신데 혹시 몇시쯤 주문하셨나요
#
# 제가 주문할 때 주소를 정확히 썼는지 확인되나요
#
# 주문자분 주소가 어떻게 되십니까
#
# 저의 주소는 #@주소#입니다
#
# 확인해 보니 말씀하신 주소가 맞습니다
#
# 네 고객님 확인되셨고요 주소지 어디로 변경하시겠어요
#
# #@주소#로 변경 부탁드려요
#
# 고객님 주소지 변경해드렸습니다
#
# 안녕하세요 저희 집 주소지는 아닌데 주소지 다르게 보낼 수 있나요
#
# 주문하실 때 입력한 주소로 배송됩니다
#
# 왜 우리집 주소가 검색이 안 되는 거예요
#
# 혹시 고객님 주소가 신규 주소지일까요
#
# 신규 주소지의 경우 아직 전산 업데이트가 안 되어서요
#
# 가장 유사한 주소지로 선택 후 상세 주소를 입력하시기 바랍니다
#
# 아닙니다 그러면 저희집 주소로 구입할게요
#
# 혹시 주소지가 어떻게 되세요
#
# #@주소# 이거요 이거
#
# 제가 실수로 주소를 잘못 적었는데 결제를 해 버렸거든요
#
# 네 아직 배송이 시작되지 않았으면 주소 좀 수정해 주셨으면 해서요
#
# 네 맞습니다 혹시 #@주소#를 #@주소#로 바꿔 주시겠어요
#
# 알겠습니다 아직 배송 전이라 주소 수정해 드렸습니다
#
# 이미 출고 대기로 넘어가서 지금 주소지 변경은 어려울 것 같은데요
#
# 주소 확인 부탁드립니다
#
# 주소는요 강원도 춘천시 #@주소# 입니다
#
# 다시 한번 불러보겠습니다 #@주소# 맞으십니까
#
# 예 주소 맞아요
#
# 주소지에 따라 이미 상품이 배송 중이기에 어렵습니다
#
# 그럼 주소지를 가까운 매장으로 할 순 없는 거죠
#
# 입력된 연락처 및 수령주소지 부재로 인해서요
#
# 아까 전화 주셔서 주소지 잘 못 입력하셔서 배송 잘 못되셨다구요
#
# 근데 저희 쪽에서도 #@주소# 거주하시는 분을 번호 알면요
#
# 이거는 주소를 잘못해갖고 보낸 걸 가지고 제가 어떻게 해요
#
# 제가 #@주소# 로도 #@주소# 로 내가 지금 문자를 넣어 드렸어요
#
# 저희도 #@주소# 로 되어 있긴 하시거든요 주소지가요
#
# 혹시 이 부분 지금 혹시 #@주소# 로 방문은 조금 어려울까요
#
# 다시 #@주소# 로 갈 거니까요 기사님한테 미리 연락을 해서요
#
# #@주소# 로 수령할 수 있도록 연락을 부탁드릴게요
#
# 고객님 연락처 성함 주소 부탁드립니다
#
# 네 #@이름# #@전번# #@주소# 입니다
#
# 그래서 이미 주소는 주문 건은 취소 되셨어요
#
# 죄송 합니다만 주문서 작성 시 주소 오기재 수취인 부재 등의 이유로요
#
# 배송지 주소를 모르고 저희 집으로 해서요 변경이 가능한가요
#
# 그게요 저희 집 주소지가 검색이 안 됩니다
#
# 저희 사이트 주소록 검색은 행정안전부 사이트에 등록되어 있습니다
#
# 행정안전부 주소 찾기 사이트라고요
#
# 저의 주소는 #@주소#입니다
#
# 말씀하신 주소로 배송이 완료되었습니다
#
# 네 맞아요 주소 불러 드리면 되나요
#
# 저의 주소는 #@주소#입니다
#
# 말씀하신 주소로 배송이 완료되었습니다
#
# 어제 주문을 했는데 배송 주소 변경이 가능할까요
#
# 배송이 시작되기 전이라면 주소 변경이 가능합니다
#
# 네 경기도 #@주소#로 변경해 주세요
#
# 기사님까지 지정됐고요 혹시 고객님 #@주소# 여기가 맞으세요
#
# 고객님 말씀대로 지금 설정하신 주소로 배송완료가 떠있네요
#
# 고객님 상품 위치 확인했는데요 지금 #@주소#로 확인되고 있습니다
#
# 아까 전화 주셔서 주소지 잘 못 입력하셔서 배송 잘 못되셨다구요
#
# 네 통화하셔서 우선은 주소지가 #@주소# 로 되어 있으시니까요
#
# 이거를 전화하셔가지고 #@주소# 해 달라고 하셔야 해요
#
# 그렇죠 우선은 상품이 이제 #@주소# 에 있단 말씀이신거죠
#
# 모르죠 내가 #@주소# 를 갖다 놨는지 아직 물건을 못 받았으니까요
#
# 기사 얘기로는 #@주소# 로다가 갔다 놨데요
#
# 고객님께서 #@주소# 로 이렇게 가셔서 확인은 좀 어려우시죠
#
# 배송지에 주소나 연락처가 잘 기재 되었는지 확인해 보셨나요
#
# 사이트 주소 좀 알려 주세요
#
# 사이트 주소는 #@URL#입니다
#
# 물품을 받으실 주소는 어디인가요
#
# 저의 주소는 #@주소#입니다
#
# 우편 저 주소대로 발송을 했거든요 반송을 했거든요
#
# 먼저 한국주소로 동까지만 작성을 해주시고요
#
# 상세주소에 해외배송으로 기재해주세요
#
# 고객님 #@주소#로 배송완료 되었다고 확인되시는데요
#
# 거기가 아니라 #@주소# 인데
#
# 주문한 주소는 #@주소#로 되어있는데요
#
# 네 #@주소#가 맞습니다
#
# 거기 지금 거 주소가 어떻게 됐어요 주소가 잘못됐다고 그러던데요
#
# 고객님 지금 여주시로 주소 잘 되어 있는 걸로 확인됩니다
#
# 그래가지고 좀 밀려 있던 거 같고 오늘 아침 여덟 시에 #@주소# 배달지에 도착해있네요
#
# 네 받으신 상태 그대로 구성품 누락 없이 저희 사이트 하단 주소로 보내 주세요
#
# 배송지를 입력하는데 주소 검색이 안 되네요
#
# 행정안전부의 도로명 조회 사이트에서 검색되는 주소를 기반으로 합니다
#
# 실제 존재하는 주소인지 확인 부탁드립니다
#
# 혹시 주소가 등록이 되어 있지 않을 수도 있어요
#
# 주소가 등록 되어 있지 않다면요
#
# 도로명 주소 도움 센터에 등록 요청을 해주시기 바랍니다
#
# 농협 계좌 보내드리고 상품 받으실 주소지 한번 알려주시겠어요
#
# 경기도 김포시 #@주소# 입니다
#
# 현재 해외 주소지로의 해외배송 서비스는 지원되지 않구요
#
# 기다려주셔서 감사합니다 주소가 경기 일산 쪽 맞으십니까
#
# 예 그리고 받으시는 분 주소 확인해주세요
#
# 고객님 경북 경산시 #@주소# 맞으신가요
#
# 경산 #@주소# 맞습니다
#
# 주문서 하나에 한 개의 주소만 입력이 가능해요
#
# 배송 주소 불러 주십시오
#
# 예 #@주소# 입니다
#
# 아뇨 저희 집 주소가 검색이 안 되거든요
#
# 주소록 검색은 행정 안전부에 등록된 정보를 기반으로 설정되었습니다
#
# 신축 건물인 경우 행정 안전부에 주소가 등록되어 있지 않을 수 있습니다
#
# 그 사이트에도 주소는 등록되어 있고요
#
# 일 대 일 문의로 정확한 주소 남겨 주세요
#
# 네 고객님 배송주소 배송 주소는 어디로 보내드릴까요
#
# 경기도 남양주시 #@주소# 에요
#
# #@주소# 로 주소 놓겠습니다
#
# 서울시 구로구 #@주소#에 있습니다
#
# 배송 주소를 잘못 입력해서 물건이 다른데로 갔어요 어떡하죠
#
# 죄송하지만 배송된 주소에서 제품을 수령해 주셔야 할 거 같습니다
#
# 고객님의 기본정보 주소지로 배송됩니다
#
# 그러실 경우 개인정보 주소지를 반드시 변경해 주시기 바랍니다
#
# 변경 전 주소로 잘못 주문을 했습니다
#
# 변경하고자 하는 주소로 기입 후 확인하시면 됩니다
#
# 수령 주소지 부재로 인해 상품이요
#
# 고객센터로 연락 주시어 고객님 정확한 주소하고요
#
# 판매처마다 발송 주소지가 달라서 각각 수령됩니다
#
# 네 주소지 변경 가능한가요
#
# 제가 #@주소#에 있는 지에스이십오로 시킨 건 맞죠
#
# 배송 주소지 변경할 수 있나요
#
# 고객님 죄송하지만 제품 출고되어 주소지 변경이 불가합니다
#
# 배송지 주소를 변경하고 싶은데요
#
# 네 그럼 고객님 주소와 연락처가 어떻게 되실까요
#
# 네 #@주소#에 #@전번#입니다
#
# 주소를 잘못 기재했는데 그럼 어떻게 하죠
#
# 강원도 #@주소#에 살고 있어요
#
# 네 고객님 주문 상품 확인되셨고요 변경 주소지 불러 주세요
#
# 네 울산시 남구 #@주소#로 바꿔 주세요
#
# 아니요 없습니다 주소지 변경 부탁해요 상담사님
#
# #@주소# 요 잠시만 기다려주세요
#
# 네 고객님 상품 받으실 주소 부탁드립니다
#
# 네 #@주소# 여기로 보내주세요
#
# 네 확인 감사합니다 주소가 전남 목포시 #@주소# 맞나요
#
# 네 주소 맞아요
#
# 지금 #@주소#로 확인되고 있습니다
#
# 네 농협 해드리고 물건 받으실 주소지 알려주세요
#
# 네 충북 청주시 #@주소# 입니다
#
# 네 주소지 변경 어떻게 하나요
#
# 배송지 주소는 주문 진행 상태에 따라 변경 방법이 상이합니다
#
# 직접 주소지 변경이 가능합니다
#
# 노트북을 사려고 하는데 배송지를 해외 주소로 할 수 있나요
#
# 출고 처리중이거나 출고 완료된 상품을 주소지 변경을 할 수 있나요
#
# 게시판 링크주소 문자 받았는데 지워졌어요
#
# 네 고객님 어떤 문의로 게시판 링크 주소 받으셨나요
#
# 링크 주소는 문자로 발송해 드리겠습니다
#
# 주소지 건물명이 변경되었는데 어떻게 하나요
#
# 행정안전부의 도로명 조회 사이트에서 검색되는 주소를 기반으로 합니다
#
# 도로명주소 도움센터에 변경 요청을 해 주시기 바랍니다
#
# 일대일 문의글로 주소지와 함께 요청해 주시기 바랍니다
#
# 저희 주소지는 태백이거든요
#
# 고객님 확인해 보니까 주소지가 구미로 되어 있거든요
#
# #@소속# 정확한 주소가 어떻게 되나요
#
# 네 저희 주소는 김포시 #@주소#입니다
#
# 정확한 주소 좀 부탁드려요
#
# 충남 당진시 신평면 #@주소#입니다
#
# 다행이네요 지금 가고 있는 중인데 주소 확인 부탁드려요
#
# 경남 거제시 #@주소#로 오시면 됩니다
#
# 빙 돌아서 가고 있었네요 주소 제대로 입력했습니다
#
# 아 그러셨군요 주소 영월군 주천면 #@주소# 입니다
#
# 강원 철원군 #@주소# 에 위치하고 있습니다
#
# 내비게이션에 혹시 어떻게 주소를 검색해야 하나요
#
# 아 주소를 #@주소#로 검색해 주세요
#
# #@소속# 정확한 주소가 어떻게 되나요
#
# 네 저희 주소는 전라북도 남원시 #@주소# 입니다
#
# 좋네요 루트 좀 보고 싶은데 주소 불러주세요
#
# 영월군 영월읍 #@주소# 입니다
#
# 고객님 이메일 주소도 말씀 부탁 드립니다
#
# 이메일 주소는 #@계정# 입니다
#
# 예약 내역은 말씀해 주신 이메일 주소로 보내 드리겠습니다
#
# #@주소# 근처 모텔 중에 지금 들어갈 수 있는곳 안내 부탁드려요
#
# 거제시 #@주소#에 있는 와이비 모텔이거든요
#
# 네 경기도 가평군 #@주소# 입니다
#
# 고객님 성함과 연락처 이메일 주소 말씀 부탁 드리겠습니다
#
# 이메일 주소는 #@계정# 입니다
#
# 아 네 거기 정확한 주소 좀 지금 불러주세요
#
# 영월군 한반도면 #@주소# 검색하시면 됩니다
#
# 홈페이지 주소 좀 알려주실래요 보고 예약해야겠네요
#
# 홈페이지 주소 안내 부탁드려요
#
# 정확인 위치 주소를 알 수 있을까요
#
# 주소는 당진시 석문면 #@주소#입니다
#
# 한번 가봐야겠네요 주소 알려주실래요
#
# 충청남도 논산시 #@주소# 여기로 가시면 됩니다
#
# 네 #@주소#입니다
#
# 홈페이지 주소 알 수 있을까요
#
# 홈페이지 주소는 #@URL#입니다
#
# 이따 방문할건데 출발 전에 주소 보내준다고 하셔서요
#
# 강원 철원군 #@주소# 입니다 예약 필수로 하셔야해요
#
# 여기 주소 좀 알려주실 수 있어요
#
# 네 주소 불러드려도 될까요
#
# 평암189 캠핑장 주소는 경남 창원시 마산합포구 #@주소# 입니다
#
# 그러면 알아서 가야겠네요 주소 안내 부탁합니다
#
# 강원도 홍천군 #@주소#로 가시면 됩니다
#
# 평암189 캠핑장인데 주소 알려주실 수 있어요
#
# 네 주소 안내 도와드리겠습니다 지금 불러드리면 될까요
#
# 네 불러드리겠습니다 경남 창원시 마산합포구 #@주소# 입니다
#
# 도착 다해가는데 주소 좀 불러달라 하려고 전화했는데 통 받지를 않아서요
#
# 갤러리펜션 주소 안내드리면 될까요
#
# 강원 철원군 #@주소# 으로 가시면 됩니다
#
# 뒷주소가 잘못되어 있어서 길을 잘못 빠졌네요 감사합니다
#
# 주소랑 번호 불러주실래요 예약 바로 해야겠어요
#
# 강원 철원군 #@주소#에 위치해 있구요 #@전번# 으로 전화하시면 됩니다
#
# 안녕하세요 러빙유카라반 캠핑장 주소를 알고 싶어요
#
# 네 고객님 당진시 고대면 #@주소#입니다
#
# 네 홈페이지 주소를 알려주세요
#
# 웨스트오브가나안 호텔 예약했는데 주소 좀 알려주시겠어요
#
# 네 웨스트오브가나안 주소 안내 도와드리겠습니다
#
# 주소 불러드려도 될까요
#
# 네 웨스트오브가나안 호텔 주소는 충북 #@주소# 입니다
#
# 네 지번주소로는 경기도 가평군 #@주소# 입니다
#
# 네 경기도 가평군 #@주소# 입니다
#
# 아 그래요 정확한 주소가 어떻게 되나요
#
# 네 저희 주소는 김포시 #@주소# 입니다
#
# 입곡마을이요 네비 찍어보려고 하는데 주소 알려주세요
#
# 네 주소 안내해드리겠습니다 경남 창원시 마산합포구 #@주소# 입니다
#
# 사이트 주소가 혹시 어떻게 될까요
#
# 아 그럼 바닷가랑 가깝겠네요 정확한 주소 좀 알려주시겠어요
#
# 주소는 당진시 석문면 #@주소#입니다
#
# 네 브라운도트호텔 하단점이요 여기 주소가 어떻게 돼요
#
# 브라운도트호텔 하단점 주소 안내 도와드리겠습니다
#
# 네 주소는요 부산시 사하구 #@주소#입니다 고객님
#
# 위치는 영월군 무릉도원면 #@주소# 입니다
#
# 당진시 순성면 #@주소#번지입니다
#
# 메일 주소 말씀해 주시면 바로 보내 드리겠습니다
#
# 알겠습니다 저 홈페이지로 예약하고 싶은데 사이트 주소 있나요
#
# 네 사이트 주소는요
#
# 펜션 주소 좀 알 수 있을까요
#
# 당연하죠 저희는 #@주소#에 위치해 있습니다
#
# 홈페이지 주소 알 수 있을까요
#
# 홈페이지 주소는 #@URL#입니다
#
# 메일로 예약하고 싶은데 이메일 주소 좀 알 수 있을까요
#
# 네 이메일 주소는 #@계정# 이거 입니다
#
# 레이어스 호텔이요 주소를 알려주실 수 있을까요
#
# 주소 안내해드릴게요 부산시 사하구 #@주소# 입니다
#
# 정확한 주소가 어떻게 되나요
#
# 예 주소는 충북 충주시 #@주소#입니다
#
# 홈페이지 주소 안내해드릴까요
#
# 네 지금 예약하게 주소 불러주세요
#
# 네 홈페이지 주소는 #@URL# 입니다
#
# 네 위치는 경기도 가평군 #@주소# 입니다
#
# 아 그래요 정확한 주소가 어떻게 되나요
#
# 네 저희 호텔 주소는 전라북도 남원시 #@주소#입니다
#
# 안녕하세요 누와즈컬리넌 호텔 주소를 못 찾겠어서요
#
# 네 맞아요 거기 주소 좀 알려주세요
#
# 주소 안내해 드리겠습니다 창원시 의창구 북면 #@주소#입니다
#
# 홈페이지 주소 안내해드릴까요
#
# 네 주소 불러주시겠어요
#
# 네 홈페이지 주소는 #@URL# 입니다
#
# 안녕하세요 왜목 오토캠핑장 주소를 알 수 있나요
#
# 네 고객님 왜목오토캠핑장은 당진시 #@주소#입니다
#
# 주소를 말씀드리면 될까요
#
# 주소와 연락처를 알려주세요
#
# 주소는 충남 당진시 신평면 #@주소#번지입니다
#
# 네 가평군  #@주소#에 위치하고 있습니다
#
# 엘마르 펜션 가고 있는중인데 주소 한번만 확인 해주시겠어요
#
# 경남 거제시 #@주소#입니다 주소 동일하실까요
#
# 아 근처로는 가고 있었는데 뒤에 상세 주소가 틀렸었네요
#
# 혹시나해서 한번 더 확인하려구요 가는중인데 주소 한번만 불러주실래요
#
# 경상남도 거제시 #@주소#로 오시면 됩니다
#
# 주소 안내 좀 다시 부탁드릴게요
#
# 충청남도 논산시 #@주소# 라고 나옵니다 고객님
#
# 이상하네요 그 주소 아까 가봤는데 중국집 주소던데요
#
# 네 #@주소#에 있는 당구장이요
#
# #@소속#죠 거기 주소 안내 좀 해주세요
#
# 네 경상북도 경주시 #@주소#입니다
#
# 아 그렇군요 혹시 모르니 주소도 그냥 불러주세요
#
# 네 담양군 담양읍 #@주소# 찾아오시면 됩니다
#
# 그럼 사이트 주소 좀 일단 불러주실래요
#
# 기존에 주신 메일 주소로 변경 내용 보내드리겠습니다
#
# #@주소# 근처에서 머물 예정이었는데 좀 멀리 있는 곳도 괜찮아요
#
# 아 그러면 주소 안내 해주시겠어요
#
# 강원 철원군 #@주소# 여기 입니다 번호 안내도 드릴까요
#
# 예약하실 고객님의 성함과 연락처 이메일 주소 말씀 부탁 드립니다
#
# 메일 주소는 #@계정# 입니다
#
# #@소속# 주소 안내 좀 부탁드립니다
#
# 네 경북 영주시 #@주소#에 위치하고 있습니다
#
# 당진 아질리아 그린 캠핑장은 당진시 대호지면 #@주소#입니다
#
# 네 경기도 가평군 #@주소# 입니다
#
# 지금 묵고있는 숙소랑 거리를 좀 봐야해서 그런데 주소 좀 불러주실래요
#
# 경상남도 거제시 #@주소#에 위치해 있습니다
#
# 게스트하우스는 서울 은평구 #@주소#에 위치하고 있습니다
#
# 주소는 당진시 #@주소#입니다
#
# 예약 홈페이지 주소 좀 알려주시겠어요
#
# 네 가서 짐부터 풀고 싶은데 네비 주소 좀 불러주세요
#
# 영월군 김삿갓면 #@주소# 찍으시면 됩니다
#
# 네 고객님 주소 안내드릴까요
#
# 충남 논산시 #@주소# 입니다 입력 되셨을까요
#
# 보경사는 경북 포항시 북구 #@주소#에 위치하고 있습니다
#
# 호텔 주소가 정확히 어떻게 되나요
#
# 예 저희 #@소속#주소는 충주시 #@주소#입니다
#
# 고객님의 연락처와 메일 주소도 말씀해 주세요
#
# 말씀해 주신 메일 주소로 예약내역 보내 드렸습니다
#
# 네 물론이죠 주소가 어떻게 되실까요
#
# 아유 감사합니다 주소는 요 #@주소#에요
#
# 네 예약했고요 주소안내 부탁드려요
#
# 주소는 경북 포항시 북구 #@주소#입니다
#
# 아 잠시만요 좀 적을게요 #@주소# 맞나요
#
# 맞습니다 네비상 도로명 주소로 위치 알려드릴까요
#
# 네 지금 차로 넘어가려구요 주소 불러주세요
#
# 네 정선군 북평면 #@주소# 찾으시면 됩니다
#
# 홈페이지 주소 알려주세요
#
# 네 고객님 홈페이지 주소 불러드리겠습니다 #@URL# 입니다
#
# 속내산 사내리캠핑장을 가려고 하는데 주소를 좀 알려주세요
#
# 네 주소 안내 도와드리겠습니다 지금 불러드려도 될까요
#
# 네 주소는 충북 보은군 #@주소# 입니다
#
# 네 충북 보은군 #@주소#요 알려주셔서 고맙습니다
#
# 오늘은 근처에서 묵을 생각이라 거기 주소 좀 불러주실래요
#
# 경상남도 거제시 #@주소# 입니다 확인 되셨을까요
#
# 네 경기도 가평군 #@주소# 입니다
#
# 음 혹시 모르니 도로명 주소도 지금 불러주세요
#
# 영월군 김삿갓면 #@주소# 찾으시면 됩니다
#
# 지금 온라인으로 예약하고 있으니까 바로 가게 주소 불러주실래요
#
# 경남 거제시 #@주소# 여기로 오시면 됩니다
#
# 아 그리고 제가 주소를 모르는데 주소 좀 알려주시겠어요
#
# 네 레이어스 호텔 주소 안내해 드리겠습니다
#
# 네 호텔 주소는 부산시 사하구 #@주소#입니다
#
# 주소는 서울 마포구 #@주소#이고 홍대합정역 3분거리입니다
#
# 나머지는 가입해서 봐야한다는거네요 홈페이지 주소 좀 주실래요
#
# 연락처와 메일 주소도 말씀해 주세요
#
# #@소속#는 서울 종로구 #@주소#에 위치하고 있습니다
#
# 아 그래요 주소를 좀 알려주세요
#
# 당진시 석문면 #@주소#입니다
#
# 홈페이지 주소 알려주세요
#
# 홈페이지 주소는 #@URL#입니다
#
# 홈페이지 주소 알 수 있을까요
#
# 홈페이지 주소는 #@URL#입니다
#
# 지금 가고 있는 중인데 주소 확인 한번만 해주실래요
#
# 경상남도 거제시 #@주소# 핀란드빌리지펜션으로 오시면 됩니다
#
# #@소속# 정확한 주소가 어떻게 되나요
#
# 네 저희 주소는 경기 김포시 #@주소#입니다
#
# 게스트하우스 주소 좀 알려주세요
#
# 저희 게스트하우스 주소는 서울특별시 종로구 #@주소#입니다
#
# 네 주소를 불러드리면 될까요
#
# 네 네비에 찍어보려구요 주소 불러주세요
#
# 보은글램핑 주소는 충북 보은군 속리산면 #@주소# 입니다
#
# 아 둥지펜션 네비 주소 불러드리면 될까요
#
# 주소는 영월군 수주면 #@주소# 이고요
#
# 정확한 위치와 주소를 알고싶어요
#
# 고객님 일성남한강콘도 주소는 경기 여주시 #@주소#입니다
#
# 캠핑장 정확한 주소가 어떻게 되나요
#
# 네 저희 주소는 충청북도 충주시 #@주소# 입니다
#
# 아 그랬나요 홈페이지 주소가 어떻게 되죠
#
# 안녕하세요 뚜벅이마을 게스트하우스 주소 알수 있을까요
#
# 네 뚜벅이마을 주소 안내해 드리겠습니다
#
# 주소는 경북 영덕군 #@주소#입니다
#
# 경북 영덕군 #@주소# 맞나요
#
# 예약을 했는데 주소를 잘못 안내받은거 같아서요
#
# 펜션 주소 안내가 필요하신걸까요
#
# 충청남도 논산시 #@주소# 입니다 되셨을까요
#
# #@주소#에 야외 테라스가 있는 한옥 민박집이 있을까요
#
# 그러시면 #@주소#에 위치한 모꼬지를 추천드립니다
#
# 네 경기도 양평군 #@주소#외 솔뜰입니다
#
# 그럼 이메일 주소 말씀해 주시겠어요
#
# 정확한 주소 알 수 있을까요
#
# 주소는 경북 구미시 #@주소#입니다
#
# 네 주소랑 가격 안내도 같이 부탁합니다
#
# 경남 거제시 #@주소#에 위치해있구요 방은 일반실 5만원입니다
#
# 영월군 김삿갓면 #@주소# 검색하시면 됩니다
#
# 터미널 도착을 했는데 아직 가지를 못했네요 주소 불러주실래요
#
# 강원도 홍천군 #@주소# 입니다 여기로 가시면 됩니다
#
# 아뇨 주소면 충분합니다 수고하세요
#
# 네 영월군 영월읍 #@주소#에 위치해있습니다
#
# 충남 당진시 석문면 #@주소#입니다
#
# 네 안녕하세요 #@주소#인데요
#
# #@주소# 근처에 무인텔 있다고 들었는데 맞나요
#
# 있으면 주소 안내 부탁드려요
#
# 네 드비취무인텔이구요 경남 거제시 #@주소#에 있습니다
#
# 네 그러시면 주소 말씀해 주시겠습니까
#
# 네 주소는요 #@주소#입니다
#
# 주소 불러주시겠어요
#
# 강원 철원군 #@주소#입니다 고석정 근처라고 생각하시면 되세요
#
# 강원도 홍천군 #@주소#에 위치해 있습니다
#
# 3만원이요 주소 알려주세요
#
# 네 주소 불러드리겠습니다 괴산군 괴산읍 #@주소# 입니다
#
# 죄송하지만 직지사 주소 알 수 있을까요
#
# 직지사 주소 안내해 드리겠습니다
#
# 주소는 경북 김천시 #@주소#입니다
#
# 예약내역 확인하실 이메일 주소도 말씀해 주시겠습니까
#
# 메일 주소는 #@계정# 입니다
#
# 네 회원님 성함과 연락처 주소 말씀해 주십시오
#
# 주소가 서울시 서초구 #@주소#입니다
#
# 해당 정보는 생년월일 성별 이메일 주소하고요
#
# 동까지 나와있는 자택 주소 발급 받고자 하는 강좌명 입니다
#
# 1대1게시판에 요청 사유와 메일 주소 남겨 주시면 가능하세요
#
# 부산시 사상구 #@주소# #@소속# 입학담당자 앞으로 보내주세요
#
# 실 거주 주소 입력하시고 회원 가입 가능하십니다
#
# #@이름#이고 번호는 #@전번# 인데 주소는 괜찮나요
#
# 네네 회원정보에 있는 주소로 방문 선생님 가실거예요
#
# 서대문구로 되어있는 그 주소 맞나요 확인만 해주세요
#
# 네 회원님 성함과 연락처 주소 말씀해 주십시오
#
# 이름이 #@이름# 연락처가 #@전번# 주소는 서초구 #@주소#이요
#
# 아 그래요 그럼 #@주소# 캠퍼스 전화번호 좀 알려주세요
#
# 네 고객님 #@주소# 캠퍼스 전화번호 안내 드리겠습니다
#
# #@주소# 캠퍼스 #@전번# 입니다
#
# 네 #@이름# 회원님 자택 주소가 서울시 마포구 #@주소# 맞으십니까
#
# 주문 완료 후 회원님께서 등록하신 이메일 주소로 발송됩니다
#
# 아 네네 회원 정보의 주소로 상담 잡아드리면 되나요
#
# 이름 #@이름#에 번호 #@전번# 이고요 네네 그 주소로 해주세요
#
# 알겠습니다 고객님 확인되셨고요 서울시 #@주소# 여기로 몇시 약속 잡아드릴까요
#
# 네 홈페이지 주소가 #@소속#인가요
#
# 네 저희 홈페이지 주소는 #@URL#이에요
#
# 네 교재 발송일 3일 전까지 변경하시면 변경된 주소로 발송해드립니다
#
# 그럼 홈페이지에서 주소 변경을 하면 될까요
#
# 그리고 화면 우측 배송지 변경에서 원하는 주소로 변경해 주세요
#
# 내일 이사할 집 주소로 정보 수정될까요
#
# 네 안녕하세요 주소 변경을 하고 싶은데요
#
# 네 주소변경 말씀이세요
#
# 방문으로 할게요 주소 좀 알려주세요
#
# 서울시 동작구 #@주소# 입니다
#
# #@주소# 교육센터 신청하신 거 맞으실까요
#
# 기초수급자 증명서와 신청 동기글 아이디를  #@주소#로 보내주세요
#
# 네 주소지 설정하셔서 신청이 불가하여 뜬 메시지 같습니다
#
# 주소도 말씀해 주십시오
#
# 주소가 서울시 송파구 #@주소#입니다
#
# 아 여기서 주소 변경이나 비밀번호도 변경 다 가능하네요
#
# 12월 3일부터 7일까지는 #@주소# #@주소# 주민 신청기간입니다
#
# #@소속#에서는 새 소식을 이메일 주소로 발송해 드리고 있습니다
#
# 네 수고하십니다 이번에 이사를 하게되서 주소변경하려고요
#
# 네 주소변경 말씀이세요
#
# 네 맞아요 주소변경이요
#
# 아 저희 #@소속#인데 #@주소# 센터라는 말씀이시죠
#
# 네 고객님 그리고 이메일 주소를 입력하시면 이메일로 보내지고요
#
# 회원님 성함과 연락처 주소 말씀해 주십시오
#
# 주소가 서울시 서초구 #@주소#입니다
#
# 안녕하세요 #@소속#회원인데 주소변경 좀 하고 싶어서요
#
# 네 회원님 자택 주소변경 원하십니까
#
# 네 #@이름#회원님 바뀐 주소 말씀해 주십시오
#
# 경기도 파주시 #@주소#입니다
#
# 회원님 경기도 파주시 #@주소# 맞습니까
#
# 저#@주소# 캠퍼스로 모의고사 신청을 했는데 주소를 바꾸고 싶어서요
#
# 아 그래요 그럼 #@주소# 캠퍼스 전화번호가 뭐예요
#
# 네 고객님 #@주소# 캠퍼스 전화번호 안내해드리겠습니다
#
# #@주소# 캠퍼스 #@전번# 입니다
#
# 네 #@주소# #@전번#이요 적어놨어요
#
# 네 알겠습니다 #@주소#로 전화할게요
#
# 혹시 메모 가능하실까요 주소 불러드릴게요
#
# 서류 보내주실 주소는요
#
# 부산광역시 사상구 #@주소# #@소속# 입학홍보처입니다
#
# 성함과 연락처 주소 말씀해 주십시오
#
# 이름이 #@이름# 연락처가 #@전번# 주소는 서초구 #@주소#이요
#
# 이사해서 주소 변경하려고 연락했어요
#
# 네네 현재 서울시 강북구로 되어있는 주소 변경 어떻게 도와드릴까요
#
# 서울시 도봉구 #@주소#로 변경해 주시면 될거 같아요
#
# 아 그 로그인은 이미 한 상태구요 제가 주소랑 정보를 좀 바꿔야 해서요
#
# 수고하십니다 #@주소# 라인댄스는 #@주소# 주민만 수강 가능한지요
#
# 네 그런데 #@주소# 주민만 수강할 수 있는지요
#
# #@주소#거주자 우선 접수의 방식이기 때문입니다
#
# 다음주 월요일부터 #@주소# 우선 등록기간이 시작됩니다
#
# 음 그래요 우편으로 접수할게요 주소 좀 알려주세요
#
# 네 주소는 부산시 사상구 #@주소# #@소속# 이고요
#
# 전화번호가 #@전번#입니다 이메일 주소도 알려드릴까요
#
# 이메일 주소도 알려주세요
#
# 이메일 주소는 #@계정# 입니다
#
# 홈페이지 주소가 어떻게 됩니까
#
# 네 홈페이지 들어가시면 이메일 주소와 팩스 번호 나와있으세요
#
# 혹시 홈페이지 사이트 주소 알 수 있나요
#
# 네 사이트 주소는 #@URL# 입니다
#
# 연간 패키지 주소 변경은 어떻게 해요
#
# 네 고객님 메모 가능하시면 팩스번호나 이메일 주소 알려드릴게요
#
# 네 알겠습니다 혹시 서류 제출처 주소 좀 알려주실 수 있으실까요
#
# 네 부산시 사상구 #@주소# #@이름# 입학홍보처입니다
#
# 회원님 성함과 연락처 주소를 말씀해 주십시요
#
# 이름은 #@이름# 주소는 동작구 #@주소#이고 #@전번#입니다
#
# 네 #@이름#회원님 #@주소#이시고 담당 선생님께서 오늘내로 전화드릴 겁니다
#
# 네 거기 #@주소# 학원 수강신청을 온라인으로 했는데요
#
# 예 저희 #@주소# 학원에서 발급이 가능하십니다
#
# 홈페이지에서 이메일 주소는 확인 했는데 수험표만 보내면 되나요
#
# 네 선생님 관리 지국은 주소지에 따라 정해져 있어서 변경이 어렵습니다
#
# 들어가시면 휴대전화 및 주소 변경이 가능하세요
#
# 휴대전화랑 주소 말고 이메일 변경은 어떻게 하나요
#
# 배송지 주소관리는 어떻게 하나요
#
# 네 배송지 즉 주소뿐만 아니라 휴대폰 번호 등 주요 정보도 수정 가능하니 바뀌면 꼭 수정해 주세요
#
# 음 고객님 혹시 가입하신 홈페이지 아이디와 이메일 주소가 같으실까요
#
# 저희는 홈페이지 아이디와 이메일 주소가 같으면 메일 발송이 안되세요
#
# 휴 알겠어요 이메일 주소를 다른 거로 다시 등록하던가 할께요
#
# 사이트 주소 좀 알려주세요
#
# 제가 #@주소# 캠퍼스로 신청을 했는데 #@주소#으로 바꾸고 싶어요
#
# 혹시 #@주소#에는 탁구반 개설이 안될까요
#
# 네 고객님 #@주소#에는 탁구반을 운영할 수 있는 장소 마련이 어려워서요
#
# 아니 #@주소# 같은 경우도 센터내에 탁구대 놓을 장소가 없다면서요
#
# 아직은 #@주소#에서 마땅한 장소를 찾지 못하고 있습니다
#
# 실은 제가요 #@주소#에 사람이 많아서 #@주소#으로 신청하려고 문의드렸거든요
#
# 네 죄송하지만 당분간은 #@주소#을 이용하시는 편이 좋으실 것 같아요
#
# 오 그렇게 가능하다면 좋네요 그러면 이메일 주소 알려주시겠어요
#
# 성함과 연락처 주소 말씀해 주십시오
#
# 주소가 서울시 종로구 #@주소#입니다
#
# 이메일 주소 좀 알려주실 수 있나요
#
# 네 이메일 주소는요 #@계정# 입니다
#
# 네 그러면 문자로 주소 보내드리겠습니다 전화번호 알려주세요
#
# 이사를 해서 주소가 변경됐는데 개인정보 변경 해 주실 수 있나요
#
# 확인되셨습니다 변경된 주소 말씀해 주세요
#
# 서울시 광진구 #@주소# 로 변경 부탁드립니다
#
# 광진구 #@주소# 에서 #@주소# 으로 변경 되셨습니다
#
# 앞으로 변경된 주소로 교재 받을 수 있는거 맞지요
#
# 맞습니다 광진구 #@주소# 로 교재와 안내물 받으시게 되세요
#
# 네 알겠습니다 주소 좀 알려주세요
#
# 부산시 사상구 #@주소# 입시홍보처입니다
#
# 저기 #@주소#에서 한지공예반을 수강하려고 하는데요
#
# #@주소#로 검색을 해도 한지공예반을 검색해도 안나와서요
#
# 저희 #@주소# 27기 문화강좌 수강신청이 9월 21일까지라서요
#
# 네 안녕하세요 주소가 변경되었는데요 전화로도 가능한가요
#
# 네 아이디는 #@계정#이시고요 변경된 주소 말씀해주세요
#
# 네 주소는 서울시 서초구 #@주소#예요
#
# 네네 #@주소# 맞으시죠 주소 변경 되셨습니다
#
# 아 졸업 증명서 제출 가능한 주소 좀 알려주실 수 있으신가요
#
# 네 부산광역시 사상구 #@주소# #@소속#입니다
#
# 혹시 현재 #@주소# 주민으로 신청하시는 건가요
#
# 아니요 #@주소# 아니고 #@주소#인데요
#
# 메일 주소가 맞으시면 회원정보수정에 메일 수신 재선택해 주면 됩니다
#
# 성함과 주소 말씀해 주시겠어요
#
# 제 이름은 #@이름#이고 주소는 서울시 동대문구 #@주소#입니다
#
# 배송지 주소를 회사로 해버렸는데요
#
# 주소 변경 원하시는 걸까요
#
# 이번 주소 변경은 해당 건에 대해서만 변경 되시는 거고요
#
# 네 알겠습니다 서울시 #@주소# 여기로 수정해 주세요
#
# 아 그러면 이메일 주소 문자로 보내주세요
#
# 혹시 주소 불러드릴까요
#
# 네 고객님 그다음 이메일 주소 입력하시면 이메일로 수강증이 발급되실 거예요
#
# 아 그래요 이메일 주소가 어떻게 되죠
#
# 고객센터 이메일 주소 알려 드릴게요
#
# 성함과 연락처 주소 말씀해 주십시오
#
# 주소가 서울시 서초구 방배동입니다
#
# 안녕하세요 거기 #@주소# 학원 수강 신청 하려고 하는데요
#
# 아니요 저희 #@주소# 학원도 온라인 수강 신청 가능하세요
#
# 네 저희가 이사를 해서요 주소를 변경해야 할 것 같아요
#
# 변경되는 주소 말씀해 주시겠습니까
#
# 아 주소 가요 #@주소# 에요
#
# 네 그러면 이번달까지는 기존 주소로 교재 배송 되시고요
#
# 다음 달부터 이사하신 주소로 변경해 드리겠습니다
#
# 메일 주소가 맞으시면 회원정보 수정에 메일 수신 체크 해제했다가 재선택해 주면 됩니다
#
# 네 집 주소가 변경돼서요
#
# 성함과 주소 그리고 연락처를 말씀해 주십시오
#
# #@이름#이고 연락처는 #@전번# 주소는 마포구 #@주소#이요
#
# 네 서울시 마포구 #@주소#이요 #@상품#수업 신청이 됐습니다
#
# 네 제가 #@주소#에 수강신청을 하고 무통장 입금까지 했거든요
#
# 네 #@주소# 바리스타 입문반이요
#
# 네 감사합니다 문의 주신 #@주소# 강좌는 24일까지 수강신청 기간이라서요
#
# 대전 #@주소#에서 진행합니다 고객님
#
# 서울 #@주소#에 있는 학원으로 알려주세요
#
# 네 저희 중고등학생 대상 학원으로 #@주소#에도 학원이 있습니다
#
# 회원가입 시 입력하신 메일 주소로 보내드립니다
#
# 제가 현재 이메일 주소가 바뀌었는데 어디서 수정해야 하나요
#
# 이메일란에 변경 하신 이메일 주소 적으시면 됩니다
#
# #@주소# 모두 유아들이 많이 분포되어 있는 걸로 아는데요
#
# #@주소#에만 유아강좌가 있는 특별한 이유라도 있는 건가요
#
# 네 회원님 #@주소# 유아강좌 개설 요청 접수하겠습니다
#
# 고객님 #@주소# 평생교육원에서 진행이 됩니다
#
# 아 #@주소#요 알겠습니다
#
# 사이트 주소는 #@URL# 입니다
#
# 고객센터 이메일 주소 좀 알려 주시겠어요
#
# 고객님 #@계정# 고객센터 메일 주소입니다
#
# 메일 주소 아니시면 회원정보에서 메일 수정하시면 됩니다
#
# 좀 번거롭네요 그 메일 주소 좀 알려주세요
#
# 예 저희 메일 주소는 #@계정#입니다
#
# 네 고객님 #@소속#대학교 #@주소#캠퍼스 상담 도와드리겠습니다
#
# #@소속#대학교 #@주소#캠퍼스 필기 시험이 따로 없나요 토익만보던데
#
# 예 일단 저희 #@소속# 사이트 주소 아시죠
#
# 네 사이트 주소가 #@URL# 맞지요
#
# 네 #@이름# 회원님 자택 주소도 말씀해 주십시오
#
# 서울시 광진구 #@주소#입니다
#
# 이메일주소 알 수 있을까요
#
# 안녕하세요 회원정보에 주소 변경 가능한가요
#
# 확인되셨습니다 변경된 주소 말씀해 주세요
#
# 서울시 강서구 #@주소# 입니다
#
# 확인하겠습니다 서울시 강서구 #@주소# 가 맞으십니까
#
# 네 성함과 주소 연락처 말씀해 주십시오
#
# 이름은 #@이름#이고 #@전번# 주소는 인천시 부평구 #@주소#이요
#
# 네 #@주소# 담당 선생님께서 이번 주 내로 전화드릴 겁니다
#
# 근데 예전 집 주소로 설정을 해놔서요
#
# 살고 계시는 주소를 말씀해 주십시오
#
# 경기도 평택시 #@주소#입니다
#
# 네 수업신청이 되셨고 #@주소# 담당 선생님께서 전화드릴 겁니다
#
# 학교 명 학교 전화번호 학교 주소를 알려주시면 등록될 수 있게 처리하겠습니다
#
# 그래요 그럼 이거 주소를 어디서 바꾸죠
#
# 고객센터 이메일 주소를 문자로 받아 보시겠어요
#
# 네 회원님 자택주소가 서울시 송파구 #@주소#로 확인이 되시는데 맞습니까
#
# 네 송파구 #@주소# 맞습니다
#
# 교재 구매하려고 하는데 주소지가 왜 검색이 안되죠
#
# 신주소거나 주소가 인식 안 되는 경우가 있습니다
#
# 저희가 주소 변경 도와 드리겠습니다
#
# 여기가 경기도 용인시 #@주소# 입니다
#
# 고객님 정보로는 가입한 이력은 없으신대 다른 이메일 주소로 가입하셔야 할 거 같아요
#
# 네 회원님 성함과 메일 주소 말씀해주세요
#
# 확인해 보니 주소를 #@계정# 으로 입력하셨네요
#
# 메일 주소가 맞으면 받으시는 메일에 받은 편지함이 가득 차있는지 확인해보시길 바랍니다
#
# 수강 등록하려고 배치 고사를 #@주소# 캠퍼스에서 봤거든요
#
# 혹시 #@주소#역 캠퍼스에서 수업을 들을 수 있나 해서 연락 드렸어요
#
# 아 네 배치 고사를 #@주소# 캠퍼스에서 보셨는데요
#
# #@주소#역 캠퍼스에 수강 등록이 가능하냐는 말씀이시죠
#
# 예 그럼 #@주소#역 캠퍼스 수강 신청해야겠네요
#
# 거기 #@주소# 학원 수강신청은 어떻게 해야 되나요
#
# 네 혹시 #@주소# 학원으로 직접 방문이 가능하신가요
#
# 고객님 이메일 주소는 맞게 입력하셨나요
#
# 네 제 다음메일 주소로 했어요
#
# #@소속# 메일주소가 스팸메일로 등록되어 있지 않으신지요
#
# 이메일 주소를 정확하게 기입하셔야 인증 및 서비스 이용이 가능하세요
#
# 네 이메일 주소만 정확하게 입력하시면 인증하는 데 문제 없으세요
#
# 네 부모님 이름이랑 이메일 주소랑 연락처요
#
# 실례지만 #@주소# 주민이신지요
#
# 아니요 저는 #@주소# 주민입니다
#
# 그런데 제가 주소 변경 좀 하고 싶어서요
#
# 그러면 나중에 보내게요 팩스 번호랑 이메일 주소 알려주세요
#
# 네 #@이름# 회원님 주소가 서울시 마포구 #@주소# 맞으십니까
#
# 네 #@주소# 맞습니다
#
# 네 배송지 주소나 자동이체 변경은 어떻게 하나요
#
# 그럼 배송지 주소 말고도 문의드려서 바꿀 수 있는 게 또 있나요
#
# 네 주소도 부탁드립니다
#
# 주소가 서울시 동작구 #@주소#입니다
#
# 그러면은 상담 예약할 수 있는 주소 좀 보내주실 수 있나요
#
# 네 성함과 연락처 주소 말씀해 주십시요
#
# 이름이 #@이름# 연락처가 #@전번# 주소는 마포구 #@주소#이요
#
# 네 #@주소#이시고 #@상품# 수업 신청하셨고요
#
# 저희 금주는 #@주소#민 접수 기간이라 신청이 안되시고요
#
# #@주소# 학원 수강증은 어디서 받나요
#
# 혹시 저희 #@주소# 학원 수강 신청을 이미 하셨나요
#
# 처음에 입력하신 이메일 주소가 일치하지 않으면 아이디찾기가 어려우세요
#
# 이메일로 성함과 연락처 주소 이메일 주소를 적어주시면 조치해 드리겠습니다
#
# 고객님 혹시 메일 주소가 정확한지 확인해 보셨나요
#
# 안녕하세요 제가 이메일 주소를 변경하고 싶은데요
#
# 아 그럼 주소지와 상관없이 이용 가능 하다는 거죠
#
# #@소속# 주소 안내해드리겠습니다
#
# 네 주소 좀 알려주세요
#
# 부산광역시 사상구 #@주소# #@소속# 이고요
#
# 안녕하세요 제가 #@주소# 라인 댄스 신청하려고 하는데요
#
# #@주소#인데 주소랑 상관이 있나요
#
# 저희  #@소속# 은 #@주소# 거주자 우선 접수입니다
#
# 이메일 주소가 어떻게 됩니까
#
# 이메일 주소는 #@계정# 입니다
#
# 네 안녕하세요 저는 #@주소# 시민은 아닌데요 수강신청을 했거든요
#
# #@주소# 시민 우선이라 하루 정도 더 기다리셔야 할 것 같으세요
#
# 네 고객님 오늘 #@주소#시민 우선 승인 처리되고 내일 될 것 같아요
#
# 네 맞습니다 그리고 주소 불러 드릴게요 메모 가능하신가요
#
# 주소가 서울시 관악구 #@주소# 입니다
#
# #@주소# 요가에 신청은 했지만 이미 승인 돼지 않았거든요
#
# 네 회원님 현재 #@주소# 요가와 생활 요가의 학습 시간이 중복되어 신청이 안되시네요
#
# 네 그러시면 #@주소# 요가 수강 등록이 끝났으니까요 수강 취소를 하시고요
#
# 네 고객님 #@소속#으로 주소 맞게 넣으신 거죠
#
# 네 회원님 미성년자의 회원가입은 #@주소# #@소속#에서 인증 절차를 거쳐야 하는데요
#
# 딴 건 다 했는데 주소 저장이 안돼서요
#
# 주소 저장 버튼을 눌러도 반응이 없다는 건가요
#
# 아니요 주소를 썼는데 자꾸 주소를 적어달라고 메시지가 떠요
#
# 혹시 도로명 주소 입력하셨을까요
#
# 네 도로명 주소 검색해서 찾은 건데 안되네요
#
# 그럼 지번 주소로 다시 입력해 주시겠어요
#
# 도로명 주소가 안될 경우 지번 주소로 검색하시면 적용 되실겁니다
#
# 아 그래요 그럼 지번 주소로 해볼게요
#
# 가입 시 학교명 검색이 안돼서 학교명과 주소 연락처 보내드리려고요
#
# 메일 주소을 변경 하려고 하는데 어떻게 해야 하는지 몰라서요
#
# 네 고객님 메일 주소 변경을 하신다는 거죠
#
# 고객님 죄송하지만 메일 주소는 변경이 불가능합니다
#
# 가입 시 입력한 메일 주소를 기준으로 서비스를 이용 가능합니다
#
# 메일 주소를 계정으로 사용하고 있습니다
#
# 잘 안 쓰는 주소라 바꾸려고 했는데 어쩔 수 없죠
#
# 연락처 주소 생년월이 등을 입력하시면 됩니다
#
# 네 #@이름# 회원님 자택주소도 부탁드립니다
#
# 서울시 광진구 #@주소#입니다
#
# 안녕하세요 혹시 배송 주소 바꿀 수 있을까요
#
# 배송 주소 관리에 대해 안내해 드리겠습니다
#
# 네 마이페이지 회원정보 배송 주소 관리에서 등록하시면 됩니다
#
# 마이페이지 회원정보 배송 주소 관리 맞지요
#
# 네 교재 구매 시 기본 주소로 설정되니 확인하시고 주문하십시오
#
# 안녕하세요 저는 #@주소# 주민인데요
#
# 현재는 #@주소# 거주자 우선 접수 기간이라서 그래요
#
# 네 처음 입력하신 이메일주소가 일치하지 않으면 비밀번호 찾기가 어려우세요
#
# 변경하실 이메일 주소 말씀해 주시면 바로 변경해 드리겠습니다
#
# 저희 대표 이메일 주소로 가족 관계 증빙서류 보내주시면 됩니다
#
# 이메일 주소는 #@계정# 입니다
#
# 무료 배포 신청했는데 주소를 좀 바꾸고 싶어서요
#
# 네 회원 정보에 등록된 주소로 보내드리면 될까요
#
# 네 같은 주소로 보내주세요
#
# 배송받으실 주소 확인하겠습니다
#
# 네 서울특별시 서초구 #@주소# 입니다
#
# 네 주소 변경 완료되었습니다
#
# 안녕하십니까 메일 주소을 변경하려고 하는데 어떻게 해야하는지 몰라서요
#
# 네 고객님 메일 주소 변경을 안내를 도와드리면 될까요
#
# 이메일 주소를 변경 시 회원 정보 수정 페이지를 먼저 들어가 주세요
#
# 하필 메일 주소를 바꿔버려서 비밀번호를 이메일로 받을 수가 없어요
#
# 네 감사합니다 메일 주소 수정은 어디서 하죠
#
# 메일 주소 수정은 마이페이지 내 정보 수정에서 변경 가능하십니다
#
# 네 확인 감사합니다 주소가 서울시 동작구 #@주소# 맞으시지요
#
# 선생님 집을 이사해서 주소도 바꾸고 셔틀도 바꾸려고요
#
# 안녕하세요 주소 변경을 하고 싶은데요
#
# 네 주소 변경 말씀이세요
#
# 회원정보수정 들어가셔서 밑에 보시면 주소 변경란이 있으세요
#
# 주소 적어주시고 저장해주시면 됩니다
#
# 혹시 팩스번호나 메일 주소 알려드릴까요
#
# 예 사이트에 적힌 주소로 보내주시면 되세요
#
# 주소창에 URL이 정확히 저희 #@소속# 주소가 맞나 확인해주시겠어요
#
# #@소속# 정확한 주소가 뭐죠
#
# 네 저희 홈페이지 정확한 주소는 #@URL# 입니다
#
# 음 주소가 정확하게 입력이 안되어있었네요
#
# 그러면 호환성 보기에 저희 #@소속# 주소를 추가해주시고요
#
# 주소창에 #@URL# 입력해주시구요
#
# 이메일 주소가 혹시 한메일이신가요
#
# 네 지금 자세히 안내 되어 있는 사이트 주소 보내드렸습니다
#
# 아니요 어플 설치하실 필요 없이 주소만 입력하면 됩니다
#
# 그러면 그 주소좀 알려주시겠어요
#
# 사이트에 들어가 온라인 클래스 주소를 추가해주세요ㅤ
#
# 네 제가 제거나 설치할 수 있는 사이트 주소 알려 드릴게요
#
# 그럼 어디 이메일주소 알려 드리면 되나요
#
# 네 이메일로 받으시겠어요 주소 말씀해 주시겠습니까
#
# 메일 주소가 맞으면요
#
# 네 주소 입력해야 하나요
#
# 교환받으시려면 기기 증상과 주소를 입력해 주셔야 신청 가능하세요
#
# 이메일 주소가 올바르지 않다는데요
#
# 이메일 주소 기입하시고 재결제 해주시면 되세요
#
# 네 사이트주소가 어떻게 되나요
#
# 이트 주소는 #@URL# 입니다
#
# 아 고마워요 그럼 한 번 보내주세요 이메일 주소 불러드리면 될까요
#
# 네 이메일 주소 부탁 드립니다
#
# #@기타# 들어왔는데 모바일 페이지 주소가 어떻게 돼요
#
# 아 그래요 주소 좀 알려주세요
#
# 가입 시 등록된 주소로 저희가 알아보고요
#
# 아 모바일이면 어떤 주소로 들어가서 수강하실까요
#
# 모바일 전용 웹 주소를 통해 수강 하셔야 오류가 발생하지 않습니다
#
# 그러시면 자세한 안내가 되어 있는 사이트 주소 보내드릴까요
#
# 크롬 주소창 자물쇠모양 아이콘을 클릭하셔서 사이트 설정 선택하시구요
#
# 네 그러면 고객님의 이메일 주소 한 번 부탁드립니다
#
# 말씀주신 주소로 메일 보내드리겠습니다
#
# 네 고객님 혹시 저희 URL주소 정확하게 입력하셨나요
#
# 네 전화번호 고객명 아동명 주소 요구 사항을 말씀해 주시면 됩니다
#
# 예 연동이 안 되고 자꾸 유효하지 않은 주소라고 떠요
#
# 자꾸 이메일 주소를 확인하라고 떠 가지고 비회원 구매도 안돼요
#
# 성함이랑 연락처 주소 말씀 부탁드립니다
#
# #@이름#구요 번호가 #@전번#이구요 경기도 부천시 #@주소#이요
#
# 메일 주소 저희한테 말씀해주시겠어요
#
# 메일 주소요 #@계정#이요
#
# 저희 이 메일주소 한번 더 확인해달라고 연락 드리겠습니다
#
# 주소는 성남 분당 #@주소# 맞으시죠
#
# 네 불러주신 주소 맞아요
#
# 주문을 위해서 성함 연락처 주소 부탁드립니다
#
# 주문자 #@이름# #@전번# 경기도 광주시 #@주소#에요
#
# 네 받으시는 분 성함과 주소 알려 주시겠어요
#
# #@이름# 경기도 평택시 #@주소#입니다
#
# 고객님 받으시는 주소 어디로 보내드리면 될까요
#
# 인천 부평구 #@주소# 요
#
# 예 그 주소는 어디로 보내드릴까요
#
# #@주소#로 보내주시면 됩니다
#
# 예 경기 #@주소#로 해드렸고요 결제는 어떻게 도와드릴까요
#
# 주문을 위해서 성함 연락처 주소 부탁드립니다
#
# 주문자 #@이름# #@전번# 서울시 종로구 #@주소#에요
#
# 저의 주소는 #@주소#입니다
#
# 네 고객님 주소가 어떻게 되나요
#
# 받을 주소는 서대문구 #@주소#입니다
#
# 네 계약자님 성함이랑 현재 주소지가 어떻게 되실까요
#
# #@이름#이고요 #@주소#에요
#
# 고객님 받으실 주소가 #@주소# 맞으십니까
#
# 네 그 주소로 보내주시면 됩니다
#
# 이름은 #@이름#이고 #@전번# 주소는 #@주소#로 했어요
#
# 배송 주소는 어디로 보내드릴까요
#
# 여기 주소가 #@주소#고 관리실로 보내주세요
#
# 네 고객님 배송주소 불러주십시오
#
# 배송주소는 #@주소#로 해주시면 됩니다
#
# 고객님 받으실 주소 알려주시겠습니까
#
# 저는 #@이름# #@전번# 아 주소 대전 유성구 #@주소# 입니다
#
# 확인 감사드립니다 고객님 주소지 말씀 부탁드립니다
#
# 경기도 #@주소#입니다
#
# 예 주소 확인 감사드립니다 무통장 입금 가능하신데요 고객님
#
# 예 고객님 조회되셨고요 계약자님 주소 확인 부탁드립니다
#
# 경기 수원시 #@주소#에요
#
# 네 고객님 주소와 성함 부탁드립니다
#
# 네 의정부시 #@주소#입니다 받는 사람은 #@이름#요
#
# 받으시는 주소 어떻게 되실까요
#
# #@주소#로 배송해 주시겠어요
#
# #@주소#으로 해서 발송 해드릴거구요
#
# 주문자분 주소는 어떻게 되시나요
#
# 저의 주소는 #@주소#입니다
#
# 수령하실 주소지도 천천히 부탁드리겠습니다
#
# 네 주소는 #@주소#입니다
#
# #@이름#이에요 번호는#@전번#이구요 주소 저장되어 있나요
#
# 아니오 비회원이시면 주소가 따로 저장되어 있지 않으세요
#
# 그러면 #@주소#요 우편번호는 #@주소#구요
#
# 계약자님 성함과 휴대폰 번호 그리고 주소가 어떻게 되십니까
#
# #@이름#이고 #@전번#에 경기도 고양시 일산서구 #@주소#입니다
#
# 아 #@이름# 고객님이요 휴대촌 번호와 주소지 말씀 주세요
#
# 전화번호는 #@전번# 입니다 주소는 서울시 관악구 @주소# 예요
#
# 예 어 서울 관악구 #@주소# 으로 해드렸습니다 입금 주실까요
#
# 감사합니다 고객님 받으실 주소 말씀해 주시겠어요
#
# 네 서울 송파구 #@주소#요
#
# 완납 후 사업자 등록증에 이메일 주소를 기재하신 후에요
#
# 네 본인 확인을 위해서 계약자분 주소도 말씀해주시겠습니까
#
# 지금 여기는 경산시 #@주소#에요
#
# 예 그리고 받으시는 분 제가 신 주소는 잘 몰라가지고요
#
# 경북 안동시 #@주소#입니다
#
# 경북 안동시 #@주소# 확인했습니다 혹시 단독 주택이신가요
#
# 그러세요 경상북도 안동시 #@주소# 맞으십니까
#
# 일단 #@이름# 이고 주소가 #@주소# 거든요
#
# 확인 감사합니다 고객님 주소 확인 부탁 드립니다
#
# 여기 주소가 #@주소# 이렇게 됩니다
#
# #@주소# 단독 주택이십니까
#
# 네 제가 다시 한번 불러보겠습니다 #@주소# 맞으십니까
#
# 예 그 주소 맞습니다
#
# 그러면은 상품 받으실 주소지 한 번 알려주시겠어요
#
# 경기도  #@주소# 이거요
#
# 물품 받으실 주소를 확인해 주세요
#
# 저의 주소는 #@주소#입니다
#
# 고객님 물건이 배송될 주소는 어디인가요
#
# 저의 주소는 #@주소#입니다
#
# 저번에도 물건 주문했었는데 다시 주소 입력을 해야되요
#
# 고객님 받으시는 주소 말씀해 주세요
#
# 경기도 고양시 #@주소#입니다
#
# #@이름# 고객님 배송 주소 어디로 보내드릴까요
#
# 네 서울 강북구 #@주소#입니다
#
# 네 회원입니다 기존 결제 방법 주소로 해 주세요
#
# 네 받으실 분 성함 주소를 말씀해 주시겠어요
#
# #@이름# 안양시 동안구 #@주소#입니다
#
# 고객님 배송 주소 어디로 보내드릴까요
#
# 지금 불러드려요 주소는 #@주소#입니다
#
# 그럼 거기 주소를 알려주시겠어요
#
# 예 그럼 주소를 안내드릴텐데요 현재 센터에 재고가 없습니다
#
# 확인 감사합니다 주소 확인도 부탁 드립니다
#
# 제 주소 말씀드릴게요 #@주소#입니다
#
# 네 고객님 주소 불러주시겠어요
#
# 서울 송파구 #@주소#입니다
#
# ...
#
# 산모의 주소지 관할 시군구 보건소와 온라인 신청이 있습니다
#
# 부부의 주소지가 다를 경우 가족관계증명서가 필요하십니다
#
# 증여자와 수증자의 주소 및 성명을 기재하고 목적물을 표시해주세요
#
# 주소 전화번호 휴대폰번호 전자우편 주소 부탁드립니다
#
# 구비서류는 임원 및 동별 대표자의 성명 주소 생년월일 하고요
#
# 다름이 아니고 제가 #@주소#공립학교에서 일합니다
#
# 자격증에 사진과 주민번호 주소가 기재 됐나요
#
# 안녕하세요 #@주소##@소속# 일반행정과 #@이름#입니다
#
# 신청인 성명과 주소 항만명 및 공사의 종류 등 입니다
#
# 메일 주소 알려주시면 제가 보내드리겠습니다
#
# 동일주소에 거주하는 형제자매도 장려금 신청대상이 되나요
#
# 형제자매 등은 동일주소에 거주하더라도 가구 구성원에 해당하지 않습니다
#
# 주소보정명령서로 주민등록등본이 발급이 안 돼요
#
# 주소보정명령서상에 피고에 대한 주소보정을 명령하고 있나요
#
# 그러면 피고의 주소가 포함된 주민등록초본을 발급할 수 있습니다
#
# 거기 주소가 어떻게 되요
#
# 예 여기가 목포시 #@주소# 입니다
#
# 목포시 #@주소# 알겠어요 이거 오늘 보내야겠다
#
# 신청은 사업장 관할 또는 주소지 관할 #@소속# 신고하시면 되는데요
#
# 의무자 주소는 개인정보에 관한 사항이라서요
#
# 구체적인 주소 피해촬영본 원본 및 게시물을 확보해 주셔야 합니다
#
# 신청인의 주소 성명 생년월일과 항만시설 사용목적이 기재되어야 하구요
#
# 그러면 사이트 주소를 좀 알려주실래요
#
# 주소는 #@URL#이구요 검색포털에 정보공개포털 입력하셔도 됩니다
#
# 네 종류가 좀 많은데요 인터넷 주소 안내해드릴까요
#
# 인터넷 주소는 #@URL#입니다
#
# 네 홈페이지 주소가 #@URL#이 맞나요
#
# 검정고시 합격증명서 한 통 주소 확인 위해 주민등록 초본 준비해주세요
#
# 우편으로는 #@소속#으로 #@주소#로 하면 됩니다
#
# 알겠어요 그거 주소가 어디에요
#
# 여기는 목포시 #@주소# 입니다 고객님
#
# 홈페이지 주소가 어떻게 되나요
#
# 안녕하세요 저는 학생이구요 #@주소#에 살아요
#
# #@주소#요 어떤 일이신가요
#
# 주민등록상 주소지를 관할하는 교육지원청에 신고하며 됩니다
#
# 우편을 보낼 주소가 어떻게 되나요
#
# 주소는 경기도 수원시 #@주소#입니다
#
# 사망자 주소지 행정복지센터 방문해주세요
#
# 네 가능 합니다 #@주소#로 발송해 주시면 됩니다
#
# 주소지의 읍 면 동 주민센터에 방문과 전자우편 온라인이 있습니다
#
# 배우자 밑으로 주소이전시 관계가 무엇으로 표시되나요
#
# 부모가 함께 주소 이전이 가능한 경우입니까
#
# 경기도 수원시 #@주소#로 우편접수하면 됩니다
#
# 네 안녕하세요 #@주소#에서 실시하는 긴급재난지원금을 받으려고요
#
# 신고인의 주소지 또는 현재지 시읍면사무소에 신고하시면 됩니다
#
# 정보통신망 구성도의 경우 아이피주소체계를 추가 요구할 수 있습니다
#
# 선생님 지원금은 해당 주소지에서 삼 개월이 넘는 시간 동안에요
#
# 신고가 되면 피신고인 주소지 관할의 #@소속#에 접수가 되고요
#
# 주소는 #@URL#로 접속하시면 됩니다
#
# 네 맞아요 이번에 #@주소#로 전학왔거든요
#
# 또한 주소지도 상관이 없으십니다
#
# 주소 좀 줄 수 있나요
#
# 사이트 주소를 알 수 있을까요
#
# 행정정보공동이용시스템의 사이트 주소는 #@URL#예요
#
# 다름아니라 주소에 따른 통학구역 안내 관련해 문의드리려고요
#
# 네 전입하려는 주소에 따른 초등학교는 어떻게 알 수 있을까요
#
# 사이트 주소 좀 불러주실래요
#
# 메모 가능하십니까 주소는 #@URL#이구요
#
# #@주소#에 번호판을 고의로 가리고 불법주차 한 차량이 있는데요
#
# 제가 사월 십오일에 주소를 이전했어요
#
# 신청인의 주소 성명 및 생년월일과 사용목적과요
#
# 이사 등 주소지 변경은 혹시 없으세요
#
# 선생님 메일주소를 알려주실 수 있나요
#
# 그럼 메일주소 불러드릴게요 #@계정#입니다
#
# 네 주소지는 관계없이 신청 가능하십니다
#
# 이번에 저희 가족이 #@주소#로 이사를 왔거든요
#
# 네 선생님 우선 #@주소#에 전입하신 것을 환영합니다
#
# 전세금 보호때문에 부모함께 주소 이전이 불가능한데요
#
# 부모 중 한사람이 주소 이전이 불가능한 경우의 전학처리 문의이실까요
#
# 주소지 동주민센터에 출생신고와 함께 출산지원금 신청 가능합니다
#
# 현역병 입영여비의 경우 입영자의 주민등록상 주소지를요
#
# 기준으로 주소지 관할 시하고요
#
# 서류는 우편으로 제출하고 싶은데 주소가 어떻게 되나요
#
# 주소는 충남 당진시 #@주소# 이고 #@소속# 앞으로 보내시면 됩니다
#
# 사업장의 주소가 변경돼서요 항만운송관련사업 등록증을 재발급 받으려고요
#
# #@주소#에도 인재육성을 위한 지원제도가 있나요
#
# 부모님이 같이 안 가도 재발급이 될까요 그리고 주소지도 바뀌었어요
#
# 제가 확인해보니 주소지는 상관이 없다고 확인이 됩니다
#
# 주소지 동행정복지센터에서 신청하시면 돼요
#
# 예 우선 주소지 근처의 해양수산청을 방문해주셔야 해요
#
# 인감증명서는 주소지 주민센터에서 인감을 등록해야 발급할 수 있습니다
#
# 사이트 주소를 알 수 있을까요
#
# 행정정보공동이용시스템의 사이트 주소는 #@URL#예요
#
# 아니요 한 번도 가본적이 없는데 주소가 어떻게 돼요
#
# 예 여기가 #@주소#인데 방문 가능하신가요
#
# 내용이 조금 많은데 메일 주소 알려주시면 메일 발송드리겠습니다
#
# 그래요 메일주소는 #@계정#입니다
#
# 선생님의 주민등록상의 주소가 #@주소#가 맞나요
#
# 신고자의 이름과 주민번호와 주소 및 연락처가 필요하고요
#
# 예 더 궁금하신 사항은 #@주소# 청렴감사실로 문의 바랍니다
#
# 사용 본거지가 #@#주소#여야 하고요
#
# 네 근데 주소가 다른 곳으로 되어 있어요
#
# 주소지의 읍면동에서 변경 신청이 가능합니다
#
# 검정고시 합격증명서 한 통 주소 확인 위해 주민등록 초본 준비해주세요
#
# 주소지 관할 동주민센터 방문하시거나 정부 이십사에서 등록 가능하세요
#
# 상속인이 피상속인의 주소지 관할 세무서에 신청할 수 있습니다
#
# 그러면 #@소속# 홈페이지 주소가 어떻게 돼요
#
# 주소지의 관할 보건소나 주민센터 또는 온라인입니다
#
# 주민등록주소지가 다를 경우 관련된 증빙자료를요
#
# 신고인의 주소지 동 행정복지센터 입니다
#
# 서류 지참하시고#@주소#민주시민생활교육과로 직접 방문해주세요
#
# 주소지의 관할 보건소나 주민센터 또는 온라인입니다
#
# 예 #@주소#에 있는 #@소속#이거든요 확인 가능하신가요
#
# 네 가능 합니다 #@주소#로 발송해 주시면 됩니다
#
# 저희 회사 주소 변경하려고 합니다
#
# 방문 신청시 주소지 읍면동 행정복지센터에서 가능합니다
#
# 인천광역시 중구 #@주소#로 보내주시면 됩니다
#
# 사업자등록으로 낸 주소는 저희 아버지 명의로 된 집인데요
#
# 등본 소유주와의 관계와 주소지 거주 사실 확인 관련 서류가 필요하세요
#
# 저희 #@소속#은 #@주소#에 위치하고 있습니다
#
# 제가 주소보정명령서로 주민등록등본을 발급하려고 하는데요
#
# 네 선생님 주소보정명령서로 주민등록등본을 발급 말씀이십니까
#
# 피고에 대한 주소보정을 명령하고 있는 주소보정명령서만으로는요
#
# 아산시 #@주소# #@소속#인데요
#
# 팩스기가 없는데 우체국도 멀고 그냥 방문 할게요 그럼 주소가 뭐지
#
# 네 여기가 목포시 #@주소# 입니다
#
# #@소속# 유치원이요 여기가 #@주소#에요
#
# 네네 저희 쪽 여기 목포시 #@주소#로 방문해주셔도 됩니다
#
# 거기 길이 #@주소# 주변인가요
#
# #@주소#는 좀 멀구요 여기 #@소속# 미용실 아세요 큰 거
#
# 예 수고하십니다 비봉장이 어디인지 주소 좀 알 수 있을까요
#
# 사업자 소재지 주소 변경이 안 되어 문의드립니다
#
# 주소 변경이 안 되었다고요
#
# 사업자 주소변경과 대표사업자 변경 방법 및 절차를 알려 주세요
#
# 주소 변경은 홈택스의 사업자등록정정 신청을 통해 변경 가능합니다
#
# 사업자등록증 정정신청서에 변경된 주소와 변경된 대표자를 기재하여서요
#
# 부천시 #@주소#로 우편을 보내 주시면 됩니다
#
# 주소지로 사실확인요청서를 발송하고 출석시 위반사실 여부를 확인합니다
#
# 그러면 주소지 관할 파출소 경찰관이 소재수사를 통해 절차를 진행합니다
#
# #@주소# #@소속# 초등학교 근처에 쓰레기 악취가 너무 나서요
#
# 홈페이지 주소 알 수 있나요
#
# 선생님께서 말씀하시는 #@주소#까지는 약 오백오십팔미터 도보로 이동하시면 됩니다
#
# 선생님께서 #@주소#에서는 중앙마을 정류장까지 약 이백십구미터 정도 이동하십니다
#
# #@주소#에 #@소속#초등학교랑 #@소속#초등학교 사거리가 있거든요
#
# 그러니까 새로 지금 삽교로에서 삽교 #@주소#쪽으로 도로 공사가 진행되고 있는데요
#
# 들리네요 그러니까 도로 공사 삽교 #@주소#에서 도청으로요
#
# 거기 주소가 어떻게 되나요
#
# 저희 #@이름#홈페이지 주소는 #@URL#입니다
#
# 상속인이 피상속인의 주소지 관할 세무서에 신청할 수 있습니다
#
# 그럼 거기 주소가 어떻게 되죠
#
# 네 여기가 부천시 #@주소# 입니다
#
# 고용보험 피보험자 주소는 어떻게 변경하나요
#
# 고용보험 피보험자 주소변경 방법에 대하여 안내해 드리겠습니다
#
# 연락처 정보에서 주소 및 전화번호 이메일 등을 수정하시면 됩니다
#
# 다름이 아니라 저희 #@주소#초등학교에 계약직 교원들이요
#
# 주소지 관할 읍면사무소 복지부서에서 상담 받아보시기 바랍니다
#
# 수원시 영통구 #@주소#에 #@기타# 초등학교 있잖아요
#
# 예 고송 #@주소#인데요 도로 왜 사 차선 도로 난데 있죠
#
# 유월 십오일에 #@주소#선착장 민원이라고 하시면서 그것도 넣고 그것도 지금 두 가지가 있어요
#
# 그 같은 기획 #@주소# 그 양식장 있잖아요
#
# 회관 홈페이지 주소 안내 도와드릴까요
#
# #@주소#가 주소가 나오나요
#
# #@주소#로 확인 해보겠습니다
#
# 네 #@주소#인지 #@주소#인지 그것은 나도 잘 모르겠어요
#
# #@주소#와 #@주소# 모두 확인이 어렵습니다 선생님
#
# 저희는 행정자치부에서 운영하고 있는 도로안내시스템을 통해서 도로명주소나 지번주소를 안내하고 있습니다
#
# 제가 #@주소#동 학원 개원하고자 문의드려요
#
# 그리고 주소는 태안군 #@주소#이고요
#
# 네 맞아요 주소
#
# 민원님께서 #@주소#에 선착장 관련해서 몇 번 민원을 제기를 하셨다고합니다
#
# 네 #@주소# 선착장 민원 해드리지 않는다고 하시면서 연결 요청하셨습니다
#
# 장애인등록증은 주민등록번호와 주소가 기재되어 있어야 합니다
#
# 주민번호랑 주소요 예 알겠습니다 감사합니다
#
# 주소지에 상시 거주하기가 어려운 환경입니다
#
# 고지서 등 각종 우편물을 다른 주소지에서 받을 수 있는지요
#
# 고지서를 받기 곤란하거나 주소지 외의 송달 받을 장소를 지정하고자 하는 경우에는요
#
# 주소지 외에 별도로 송달 받을 장소가 없는 경우에는요
#
# 제가 #@주소#에서 다른 동네로 이사했거든요
#
# 주소 이전시 운송사업증 어떡해야하죠
#
# 홈페이지에 어떻게 접속할 수 있어요 주소 좀 알려주실래요
#
# 네 저희 홈페이지 주소가 #@URL#이고요
#
# #@주소# 인근이요 소음이 너무 심해요
#
# 저희 여기 목포시 #@주소# 로 방문해주시면 됩니다
#
# 세 지점의 전화번호와 주소를 모두 안내해드리겠습니다
#
# #@소속# 홈페이지 주소가 #@URL# 맞나요
#
# 네 그럼 방문하게 주소 좀 알려주세요
#
# 예 #@주소# 입니다
#
# 그러면 여기 #@주소# 쪽에도 설치를 요청할 수 있을까요
#
# 지금 살고 있는 오피스텔에서 사업장 주소로 등록이 가능할까요
#
# 전입 신고한 주소지 사업자 등록 신청에 대해 거부가 될 수 있습니다
#
# #@주소#이라고 거기 길 이렇게 크게 도로 내는 데거든요
#
# #@주소#이십니까 제가 #@주소# 확인해보겠습니다
#
# 여보세요 #@주소##@소속# 총무과 #@소속#주무관입니다
#
# #@소속# #@주소#에 방문하면 구입 가능합니다
#
# 법인등기부상의 대표이사의 주소지 등을 확인해서요
#
# 그런데 처음부터 송달이 안 되는 주소지임을 알았다면요
#
# 신청시 구비서류는 주소지 임대차 계약서와 신분증입니다
#
# 주소지 임대차 계약서요
#
# 네 그리고 자녀분 주소지 주민센터나 온라인신청을 통해 유아학비 지원 재신청 가능하세요
#
# 그랬나요 혹시 주소좀 제 핸드폰 번호 #@전번#으로 보내주실 수 있나요
#
# 예 말씀하신 번호로 주소 보내드릴게요
#
# 제가 보내드리는 주소에 들어가서 확인해보시면 알 수 있습니다
#
# 유지원 주소나 연락처는 없는 데 정보는 볼 수 없나요
#
# 수원시 영통구 #@주소#에 #@기타# 초등학교 있잖아요
#
# 안녕하세요 #@주소# #@소속#입니다
#
# 혹시 기관 주소가 어떻게 되나요
#
# 네 #@주소#인데요 시청 옆 쪽에 있습니다
#
# 거기 인터넷 주소가 어떻게 되나요
#
# 우편 주소는 부천시 #@주소#입니다
#
# 안녕하세요 #@주소# 교육청 맞지요
#
# 선생님의 주민등록상의 주소가 #@주소#가 맞나요
#
# 거기 주소가 뭐에요
#
# 네 여기가 목포시 #@주소# 입니다
#
# 목포시 #@주소# 알겠어요 방문해야겠네요
#
# 그런가요 근데 제가 홈페이지 주소를 모르는데요
#
# 그러시면 제가 고객님 핸드폰 번호로 주소 보내드려도 될까요
#
# 네 말씀해 주신 천안시 동남구 #@주소#까지는 도보로 약 이분 정도 소요 이동을 하셔야 됩니다
#
# 사업장 관할 또는 주소지 관할 세무서장에게 신고 하셔야 합니다
#
# #@주소#하고 #@주소#하고 중간에 저수지 댐 인근이라고 하셨어요
#
# 네 주소를 불러주시겠어요
#
# 여기는 성북구 #@주소#입니다
#
# 경기도 내 주소지에서 거주하는 학생이면 됩니다
#
# 다른게 아니라요 제가 #@주소# 이곳 저곳 다니는데요
#
# 우선은요 #@주소#에는 여덟 개의 공공도서관이 있습니다
#
# 안녕하세요 저 지금 #@주소# 휴양 시설 관련 해서요
#
# #@주소# 휴양 시설이 많이 파손되고 노후가 많이 돼서요
#
# #@주소# 휴양 시설 맞으시죠
#
# #@주소#입구 정류장에서 하차 가능합니다
#
# 그러시면 목포시 #@주소#로요 신청서랑 허가증 보내주세요
#
# 죄송해요 기산동에 있는 #@주소#에요
#
# #@주소# 관할 특수교육지원센터 전화번호를 알려주시겠어요
#
# 네 혹시 내용이 많으면 볼 수 있는 인터넷 주소라도 주세요
#
# 네 확인해보니 내용이 조금 많은데 인터넷 주소 적으시겠어요
#
# 접속주소는 #@URL#입니다 선생님
#
# 사용 본거지가 #@#주소#여야 하고요
#
# 지금 #@주소#에 거주하고 있는데요 뭐 좀 물어봅시다
#
# 내년 이 월에 #@주소#로 이사할 예정인데요
#
# 주소를 제 핸드폰 번호 #@전번#으로 보내주실 수 있나요
#
# 예 말씀하신 번호로 주소 보내드릴게요
#
# 제가 보내드리는 주소에 들어가서 확인해보시면 알 수 있습니다
#
# 네 주소 말씀 주시면 안내드리겠습니다
#
# 네 주소는 #@주소# 입니다
#
# 지역 공제회 홈페이지에 접속하시면 되는데 주소를 알려드릴까요
#
# 네 주소랑 공제회 연락처도 알려주세요
#
# 홈페이지 주소는 #@URL#이구요 #@전번#으로 문의주시면 됩니다
#
# 충남 아산시 #@주소# #@소속#
#
# 충남 아산시 #@주소# #@소속#이 출발지입니다 #@소속#예요
#
# 다음 가사 확인해 보겠습니다 주여 나의 병든 몸을 지금 고쳐주소서
#
# 주소 좀 확인하려고 하는데요 주소가 공주시 공수원로 #@주소#거든요
#
# 공주시 공수원로 #@주소#여기가 어딘디요
#
# 말씀하신 공주시 우성면 공수원로 #@주소#확인해 보겠습니다
#
# 불편하셨겠어요 혹시 웹 주소 확인되시나요
#
# 네 주소 있구요 배송 안되서 환불 해달라고 했는데요
#
# 지금 여기가 #@주소#로 주소가 돼 있는데요
#
# 거기가 #@주소# 국도인가 몇 번 국도였던거 같아요
#
# 저는 #@주소# #@소속# 공무원이에요 수고하십니다
#
# 서울시 서초구 #@주소#에 방문하면 구입할 수 있습니다
#
# 네 선생님께서 문의 주시는 도로가 삽교에서 도청 간 도로공사 중 삽교 #@주소#라고 하셨습니다
#
# 네 안양시 #@주소#에 교통대책이 있을까요
#
# 당초 발급건을 선택 후 받으실 분의 메일주소를 입력하시면 됩니다
#
# 네 광정면으로 공주시 광정면으로 검색 결과 주소 확인이 어려웠습니다
#
# 네 여기는 #@주소#인데요
#
# 홈페이지 주소를 일단 좀 알려주세요
#
# 홈페이지 주소는 #@URL#입니다
#
# 네 현재 주소지에서 비슷한 거리에 초등학교가 세 군데 있어서요
#
# 네 민원인의 거주지 통반주소를 기준으로 정보 제공해드리고 있어요
#
# 혹시 저희집 통반 주소를 모를 경우에는 어떻게 하나요
#
# 그러시면 주민센터에 문의하시고 주소지를 알 수 있습니다
#
# 대구에 있는 #@주소#입니다
#
# 화성 #@주소# 경로 문의했었는데요
#
# #@주소# 정류장에서 하차해주시면 됩니다
#
# 네 그럼 그렇게 해야 되겠네 버스타고 #@주소#에서 내리면 되는거죠
#
# 여기 파주시 #@주소#입니다
#
# 거기 주소를 좀 알려주실 수 있나요
#
# 해당 부서의 주소는 #@주소#입니다
#
# 예 당진터미널에서 #@주소# 가려는데요
#
# 말씀하신 #@주소#이 당진시에 위치한 #@주소# 맞으십니까
#
# 선생님 #@주소# 어느 곳으로 도착하실 예정이신가요
#
# #@주소# #@소속#로 가려고요
#
# 홈페이지 주소를 좀 알려주실 수 있을까요
#
# 네 홈페이지 주소는 #@URL#입니다
#
# 그거 작성해서 보내라고요 주소가 어디에요
#
# 네 목포시 #@주소# 입니다 고객님
#
# 우선 지급대상자 주민등록상 주소지 관할 지자체가 기준이 되는데요
#
# 지급대상자의 주소지 관할 지자체로 신청해야 합니다
#
# 네 거기 주소가 어떻게 돼요
#
# 여기가 목포시 #@주소# 입니다
#
# 사이트 주소를 안내해드릴까요
#
# 그러면 주소도 같이 알려주세요
#
# 제가 #@주소#에 있는 #@기타# 음식점을 갔는데요
#
# 주소는 경기도 수원시 #@주소#입니다
#
# 주소가 #@URL#이 맞나요 지난번에 들어가본 것 같긴 한데요
#
# #@소속#으로 제출했는데 #@이름#이고 #@주소#예요
#
# 그러면 도에서는 #@소속#에 있는 #@주소# 국도인가 거기는 해요 안 해요
#
# 그러시면 목포시 #@주소# 여기로 오시거나 우편으로 보내주세요
#
# 네네 목포시 #@주소# 알겠습니다 그럼 얼마나 걸려요
#
# 출판사 이름 및 소재지 대표자의 성명 및 주소입니다
#
# 네 신고가 들어가면 주소지로 출석요청을 해서 처리하게 됩니다
#
# 제가 #@주소#에 살고 있는데 가까운 경찰서 안내 가능할까요
#
# 네 #@주소#에 있는 경찰서가 가깝네요
#
# 주소지를 옮긴 경우 전학을 하지 않고도 전학이 될까요
#
# 옮겨진 주소로 중학교 배정을 받을 수 있나 해서요
#
# 중학교 배정은 주소지가 아닌 초등학교를 기준으로 정합니다
#
# 때문에 주소지만 옮긴 경우는 옮겨진 주소로 배정을 받을 수 없습니다
#
# 방문 할 주소가 어떻게 되나요
#
# 방문 주소는 경기도 수원시 #@주소#입니다
#
# 특수교육지원센터가 #@주소#에도 있나요
#
# 네 #@주소#에 위치하고 있으며 전화번호는 #@전번#입니다
#
# 방문신청시 주소지의 읍면동에서 가능하십니다
#
# 네 천안에서 화성 #@주소#를 가려고 하는데 버스 타는 거 말고
#
# 동일 사업장 주소에 사업자등록을 각각 따로 낼 수 있는지 궁금합니다
#
# 이메일 주소 말씀해주시면 파일 첨부하여 전송하겠습니다
#
# 네 제 주소는 #@계정#입니다
#
# 네 말씀해주신 주소로 전송하겠습니다
#
# 선생님의 주소지에 해당하는 주민센터에 방문하시면 됩니다
#
# 신청 가능한 홈페이지 주소 알려주세요
#
# 접속하셔서 주소나 학교명을 검색하시면 됩니다
#
# 네 선생님 우선 주소지가 관내에 있어야 하고요 관할 어촌계에서요
#
# 확인 가능한 홈페이지 주소 안내 부탁드려요
#
# 거기 주소가 어떻게 되나요
#
# 네 홈페이지 주소는 #@URL#이구요
#
# 제가 주소를 안내해 드릴까요
#
# #@주소#검색하셔서 방문하시면 됩니다
#
# 알려드린 주소가 #@소속# 주소입니다
#
# 네 거기 근데 주소가 어떻게 되요
#
# 저희 여기가 목포시 #@주소#입니다
#
# 주소지 주민센터에 가셔서 자격변경 신청 하시면 됩니다
#
# #@주소#교육청 인력풀에 등록 신청 하려고 하는데요
#
# #@주소#교육청 인력풀과 별개로 생각하시면 됩니다
#
# 제가 따로 #@주소#교육청이 인력풀 등록하면 되나요
#
# #@주소# 양식장 시설 설치와 운영을 할 때 인허가 절차 알려주세요
#
# #@주소#도서관 이용하는데 불편사항이 있어서요
#
# 교습자의 주소지를 관할하는 지역교육지원청에 신고해야 합니다
#
# 거기서 주소지 관할 진로체험지원센터에서 승인 누르시고요
#
# 배정 받은 중학교 배정통지서와 주소가 옮겨진 주민등록등본이 필요해요
#
# #@소속# 정보공개 홈페이지 주소가 #@URL#이구요
#
# 메일 주소 좀 불러주시겠어요
#
# 여기가 잠시만요 세종특별자치시 #@주소#에요
#
# 주소에 따라서 통학구역이 다르잖아요
#
# 전입하려는 주소에 따른 초등학교는 어떻게 알 수 있을까요
#
# 온라인 주소는 #@URL#입니다
#
# 맞아요 지금 #@소속#중학교를 다니고 있는데 #@주소#로 가요
#
# 이사 간 주소로 전학 가능한 중학교를 확인해 드릴까요
#
# #@소속#중학교는 #@주소#의 #@소속# 학구에요
#
# 주소지에 상시 거주하기가 어려운 환경입니다
#
# 고지서 등 각종 우편물을 다른 주소지에서 받을 수 있는지요
#
# 주소지 외에 별도로 송달 받을 장소가 없는 경우에는요
#
# 용인시 기흥구 #@주소#이요
#
# 예 수고하십니다 여기가 #@주소# 아파트 관리사무소 거든요
#
# 네 #@주소# 아파트 관리사무소에서 전화 주셨고요
#
# 네 맞습니다 주소 또는 학교명으로 검색 가능하시고요
#
# 여기가 #@주소#인데 주민센타 앞에서 공주여중으로 가는 버스 있나요
#
# 네 초등학교는 해당 주소지에 설정된 통학구역에 따라 배정 됩니다
#
# 혹시 여기가 #@주소#인데 통학구역에 해당되는 학교를 알 수 있을까요
#
# 네 인터넷을 통해 확인 가능하시구요 제가 주소를 알려드릴게요
#
# 학구도안내서비스라는 사이트이구요 주소는 #@URL#입니다
#
# 여기에 접속해서 주소로 검색해보면 되나요
#
# 네 맞습니다 해당 주소에 배정된 학구와 학교를 확인하실 수 있습니다
#
# 방문하려면 어디로 가야 하나요 주소 좀 주세요
#
# 네 여기가 부천시 #@주소#입니다
#
# 그 #@주소# 공사현장 인데요 외부에 씨씨티비가 설치되있는데요
#
# 경기 북부 #@주소#입니다
#
# 그 후 해당 주소를 검색해보시면 확인 가능합니다
#
# 네 주소 알려주시면 그쪽으로 방문할게요
#
# 예 #@주소# 입니다
#
# 그럼 어디로 보내면 돼요 주소 알려주세요
#
# 예 #@주소# 입니다
#
# 홈페이지 주소 안내 부탁드려요
#
# 다른게 아니라요 제가 #@주소# 이곳 저곳 다니는데요
#
# 주소지 관할 주민 센터에 방문하셔서 신청하면 됩니다
#
# 가족의 성명 주민등록번호 및 주소 등 개인정보 제외하고 공개합니다
#
# 거기는 주소가 어떻게 되나요
#
# #@소속# 정보공개 홈페이지 주소가 #@URL#이구요
#
# 맞습니다 지금 세종시 #@주소#에 살고 있는데요
#
# #@주소#에 거주중이시면 #@소속# 초등학교로 확인 됩니다
#
# 중학교는 #@주소#학군인 #@소속# 중학교에 입학 하셔야 합니다
#
# #@주소# 거주중이시면 세종시 소재 모든 일반고등학교 진학 가능합니다
#
# 이메일 주소 알려주시면 보내드리겠습니다
#
# #@주소#내 안전체험관 위치 안내 부탁드려요
#
# 현재 #@주소#시민체험관 두 곳 #@주소#교육관 총 세 곳이 있습니다
#
# 여기가 지역이 #@주소#입니다
#
# 선생님 성함과 주소 그리고 연락처 말씀 부탁드립니다
#
# 주소는 #@주소#인데 확인되나요
#
# 홈페이지 주소가 어떻게 되나요
#
# 홈페이지 주소는 #@URL#입니다
#
# #@주소#로 직접 방문하시거나 전화상담 가능합니다
#
# #@주소# 내 유치원 관련한 문의 좀 드리려고 하는데요
#
# #@주소# 내 유치원 말씀이십니까
#
# 그런데 여기가 다 #@주소#랑 멀지 않나요 도보로는 못 가잖아요
#
# 현재 #@주소# 조성에 따라 증가하는 원아를 배치할 수 있도록 노력중입니다
#
# 그럼 #@주소#아파트에서 도보로 가능한 유치원도 신설 되나요
#
# 그러면 혹시 두 버전이 주소가 다른건가요
#
# #@주소# 추모의 집 사용 신청하려고 하는데요
#
# 우선 #@주소#에 주민등록을 뒀거나 소속이시거나요
#
# 말씀하시는 곳 주소가 어떻게 되시나요
#
# 여기 원주시 #@주소#에요
#
# 서류를 첨부해서 주소지 관할 구청장에게 제출해주시면 돼요
#
# 제가 있는 곳은 #@주소# 에요
#
# 예 수고하십니다 제가 이번에 #@주소# 아파트에 입주예정인데요
#
# 홈페이지의 큐알코드 또는 웹사이트 주소를 통해 수강신청을 받고 있습니다
#
# 홈페이지 주소 안내 부탁드려요
#
# 부천시 #@주소#로 우편 업무가 가능하십니다
#
# 일단 주소지에서 갈 수 있는 학교를 확인하실 수 있는 방법은요
#
# 사업자의 주소 또는 거소를 사업장으로 하여 신청이 가능하십니다
#
# 이메일 주소가 어떻게 되나요
#
# 이메일 주소는 #@계정#입니다
#
# 우편 제출 주소는 어떻게 되나요
#
# 주소는 경기도 수원시 #@주소#입니다
#
# 입국 후 주소지 주민센터서 처리하시거나요
#
# 온라인 #@주소#홈페이지 들어가주셔서 재신청해주세요
#
# 홈페이지 주소 좀 알 수 있을까요
#
# 안녕하세요 #@주소# 학원의 정규 교습 시간이 궁금해서요
#
# 여기가 목포시 #@주소# 입니다 고객님
#
# #@주소# 근처에서 구멍이 나서요
#
# 네 초등학교는 해당 주소지에 설정된 통학구역에 따라 배정 됩니다
#
# 혹시 여기가 #@주소#인데 통학구역에 해당되는 학교를 알 수 있을까요
#
# 네 인터넷을 통해 확인 가능하시구요 제가 주소를 알려드릴게요
#
# 학구도안내서비스라는 사이트이구요 주소는 #@URL#입니다
#
# 여기에 접속해서 주소로 검색해보면 되나요
#
# 네 맞습니다 해당 주소에 배정된 학구와 학교를 확인하실 수 있습니다
#
# 주소 이전시 운송사업증 어떡해야하죠
#
# 먼저 이사하신 주소지를 조회 한 후에요
#
# 역량 개발 센터 거기는 홈페이지 주소가 어떻게 되나요
#
# 문자에 있는 링크 주소 및 아이디로 참여하실 수 있습니다
#
# 아니요 정확한 주소만 있으면 확인 가능합니다
#
# 네 현재 주소지에서 비슷한 거리에 초등학교가 세군데 있어서요
#
# 네 민원인의 거주지 통반주소를 기준으로 정보 제공해드리고 있어요
#
# 혹시 저희집 통반 주소를 모를 경우에는 어떻게 하나요
#
# 그러시면 주민센터에 문의하시고 주소지를 알 수 있습니다
#
# 링크 주소 알려주셔서 감사합니다
#
# 말씀주신 주소가 #@URL#이 맞나요
#
# 일반적으로 집 주소에 속하는 군내 거주지 두 세군데를 뽑아요
#
# 여기가 목포시 #@주소# 입니다 고객님
#
# 방문은 저희 여기 목포시 #@주소# 로 오시면 되구요
#
# 그러시면 목포시 #@주소# 로 우편 보내주시면 됩니다
#
# 상속인이 피상속인의 주소지 관할 세무서에 신청할 수 있습니다
#
# 네 고객님 그러시면요 여기 목포시 #@주소# 방문 해주시거나요
#
# 아니면 같은 주소로 우편으로 신고서랑 이거 문자로 보내드릴게요
#
# 거기 우편 번호랑 주소 알 수 있을까요
#
# 네 #@번호#이고요 #@주소#입니다
#
# 혹시 그러면 #@소속# 홈페이지 주소를 알려주실 수 있나요
#
# 사이트 주소는 #@URL#이시고 접속하셔서 공지사항 확인해주시면 되세요
#
# 그 #@주소# 자연휴양림 있죠
#
# #@주소# 자연휴양림 담당 부서를 확인 해보겠습니다
#
# 혹시 주소 좀 보내주실 수 있을까요
#
# 방문 신고를 할 경우 주소가 어떻게 되나요
#
# 경기도 수원시 #@주소#로 방문하면 됩니다
#
# 안녕하세요 #@주소# 십오 단지에 살고 있는데요
#
# 세종시 #@주소# 맞으십니까
#
# 맞습니다 #@주소#에서 갈 수 있는 중학교는 어디인가요
#
# 저는 #@주소#에 살고 있어요
#
# #@주소#의 경우는 근거리 학교가 #@소속#중학교 입니다
#
# 전학 학교에 주소 변경 서류를 제출하시고요
#
# 사이트 주소 알려주세요
#
# 네 사이트 주소는 #@URL# 입니다
#
# #@소속#가 사이트 이름인가요 주소가 어떻게 돼요
#
# 주소는 #@URL#이고 #@소속#에 #@소속# 검색 접속 가능합니다
#
# 현실을 그대로 반영한 작품. 이것이 대한민국의 현주소이다.
#
# 주님 저를 당신의 도구로 써주소서. 위로받기 보다는 위로하며, 사랑받기 보다는 사랑하게 하소서. 제가 사랑받지 않음을 두려워 하지 않고, 언제나 사랑하게 하소서 아멘.
#
# 영화를 보다 낮익은 주소가 나와 화들짝 놀랐습니다. 어쩌면 비슷한 시기에 비슷한 장소에서 지나쳤던 사람일 수 있겠다는 생각과 함께요. 영화 잘 봤습니다. 모두 응원합니다. 감사합니다.
#
# 우리나라 교육의 현주소.
#
# 이건 엄청난 명작. 평점을 높여주소서.
#
# 물좀주소가 왜 돈좀주소로 들리는지..결말이 좀 빠르지만 나머진 흠잡을때가 없다.굿
#
# 짱짱 그리고 저 구멍가게 어딘지 알았어요! 실제로 물건 많아요. 구멍가게 주소가서울 은평구 응암로34길 16-1옆이 에요!한번씩 가보세요 강추!
#
# 법이 제자리에있는게아니다 이리저리 왔다갔다 돈있고 권력이있으면 그쪽으로 쏠린다 돈없고 힘없는 사형수 돈많고 힘있는 사형수 너무나도 차원이 틀린 결말 좌파우파를 떠나 돈있고 힘있으면 장땡인 대한민국의 현주소 10년이 지나도 변함없고 앞으로도 변함없다
#
# 이 영화 어디서 보죠? 꼭 보고 싶은데 아시는분 제네이버메일에 주소좀...
#
# 이런 객관적, 시사적, 교훈적인 영화가 5/29일 현재 전국 5개 개봉관에서만 상영중... 그리고 관람객평점(9.57)과 네티즌평점(8.40) 사이의 불균형 = 수꼴알바들의 지대한 공헌; 바로 이게 막장으로 치닫는 대한민국의 현주소!!!
#
# 이 영화를 다시 볼 수 있게 해주소서
#
# 현실을 그대로 반영한 작품. 이것이 대한민국의 현주소이다.
#
# 주님 저를 당신의 도구로 써주소서. 위로받기 보다는 위로하며, 사랑받기 보다는 사랑하게 하소서. 제가 사랑받지 않음을 두려워 하지 않고, 언제나 사랑하게 하소서 아멘.
#
# 영화를 보다 낮익은 주소가 나와 화들짝 놀랐습니다. 어쩌면 비슷한 시기에 비슷한 장소에서 지나쳤던 사람일 수 있겠다는 생각과 함께요. 영화 잘 봤습니다. 모두 응원합니다. 감사합니다.
#
# 우리나라 교육의 현주소.
#
# 이건 엄청난 명작. 평점을 높여주소서.
#
# 물좀주소가 왜 돈좀주소로 들리는지..결말이 좀 빠르지만 나머진 흠잡을때가 없다.굿
#
# 짱짱 그리고 저 구멍가게 어딘지 알았어요! 실제로 물건 많아요. 구멍가게 주소가서울 은평구 응암로34길 16-1옆이 에요!한번씩 가보세요 강추!
#
# 법이 제자리에있는게아니다 이리저리 왔다갔다 돈있고 권력이있으면 그쪽으로 쏠린다 돈없고 힘없는 사형수 돈많고 힘있는 사형수 너무나도 차원이 틀린 결말 좌파우파를 떠나 돈있고 힘있으면 장땡인 대한민국의 현주소 10년이 지나도 변함없고 앞으로도 변함없다
#
# 이 영화 어디서 보죠? 꼭 보고 싶은데 아시는분 제네이버메일에 주소좀...
#
# 이런 객관적, 시사적, 교훈적인 영화가 5/29일 현재 전국 5개 개봉관에서만 상영중... 그리고 관람객평점(9.57)과 네티즌평점(8.40) 사이의 불균형 = 수꼴알바들의 지대한 공헌; 바로 이게 막장으로 치닫는 대한민국의 현주소!!!
#
# 이 영화를 다시 볼 수 있게 해주소서
#
# 현실을 그대로 반영한 작품. 이것이 대한민국의 현주소이다.
#
# 주님 저를 당신의 도구로 써주소서. 위로받기 보다는 위로하며, 사랑받기 보다는 사랑하게 하소서. 제가 사랑받지 않음을 두려워 하지 않고, 언제나 사랑하게 하소서 아멘.
#
# 영화를 보다 낮익은 주소가 나와 화들짝 놀랐습니다. 어쩌면 비슷한 시기에 비슷한 장소에서 지나쳤던 사람일 수 있겠다는 생각과 함께요. 영화 잘 봤습니다. 모두 응원합니다. 감사합니다.
#
# 우리나라 교육의 현주소.
#
# 이건 엄청난 명작. 평점을 높여주소서.
#
# 물좀주소가 왜 돈좀주소로 들리는지..결말이 좀 빠르지만 나머진 흠잡을때가 없다.굿
#
# 짱짱 그리고 저 구멍가게 어딘지 알았어요! 실제로 물건 많아요. 구멍가게 주소가서울 은평구 응암로34길 16-1옆이 에요!한번씩 가보세요 강추!
#
# 법이 제자리에있는게아니다 이리저리 왔다갔다 돈있고 권력이있으면 그쪽으로 쏠린다 돈없고 힘없는 사형수 돈많고 힘있는 사형수 너무나도 차원이 틀린 결말 좌파우파를 떠나 돈있고 힘있으면 장땡인 대한민국의 현주소 10년이 지나도 변함없고 앞으로도 변함없다
#
# 이 영화 어디서 보죠? 꼭 보고 싶은데 아시는분 제네이버메일에 주소좀...
#
# 이런 객관적, 시사적, 교훈적인 영화가 5/29일 현재 전국 5개 개봉관에서만 상영중... 그리고 관람객평점(9.57)과 네티즌평점(8.40) 사이의 불균형 = 수꼴알바들의 지대한 공헌; 바로 이게 막장으로 치닫는 대한민국의 현주소!!!
#
# 이 영화를 다시 볼 수 있게 해주소서
#
# 물 좀 주소... 목마르요...!!!
#
# 반전이 있거나 박진감 넘치는 액션영화는 아니지만, 우리나라 정치의 현주소와 비슷한 모습이 많아 흥미롭게 봤습니다.
#
# 가족을 보호하는 아버지가 감동이 아니면 뭐가 감동이냐? 질질짜는 슬픈 드라마를 원하면 주소를 잘못찾았다 니 눈엔 이 영화의 장르도 안보이냐? 아님 한국영화개봉때마다 외국영화에 악평쓰는 알바냐???
#
# 시기적절한 영화였습니다. 라모씨는 실제 주인공이라고 하는데, 그 의지가 많은 생각을 갖게하네요. 흥미위주의 영화가 판을 치는 세상에 한번쯤 우리의 현주소를 뒤돌아보게하는 영화입니다. 추천합니다.
#
# 잔인하지만 현실... 한국의 현주소
#
# 저에게도 당신의 은총을 베풀어 주소서.
#
# 주여 나를 평화의 도구로 써 주소서
#
# 참신함과 패기를 상실한 국내단편의 현주소.
#
# 표절끝판왕 한국영화의 현 주소
#
# 오스틴파워가 차리리 낫다. 제목에서 007 좀 제발 빼주소
#
# 막장 드라마는 아니지만 편견과 stereotyping 을 조장하는 스토리에 골이 아프다. 한편으로는 이게 대한민국의 현주소인가 싶어 안타깝기도 하고. 맨날 징징 짜는 윤은혜 캐릭터에 오그라든 손발 펴느라 고생 좀 했다. 후반부에선 소재 고갈로 질질.
#
# 20살때 봤다.. 아직도 생생하게 기억난다. 대한민국 공포영화의 현주소.
#
# 이게 현 우리나라 만화영화의 현 주소.
#
# 한국교회의 현주소가 거지같음은 공감한다. 허나 진보혹은 진보정당 부류로 분류되는 성공회대(미국대사 테러한 김기종이 외래교수로활약)교수들의 인터뷰는 김정일에게 박근혜 욕하라고 하는것 처럼 거북함이 느껴졌다. B급최면영화...별점은 돈주고사나보다...ㅉ
#
# 매우 정치적 색이 강한 우리나라 필름의 현주소...
#
# 하나님, 저질코미디에서 구원해주소서!
#
# 억지 설정의 역겨운 드라마 개막장한민국 드라마의 현주소
#
# 돈 좀 주소.. 가 더 적합한 제목같다..
#
# 한국영화의 현주소...
